# %% [markdown]
# referensi https://www.analyticsvidhya.com/blog/2021/04/forward-feature-selection-and-its-implementation/

# %%
# # instal library mlxtend
# %pip install mlxtend

# %%
# Import Library
import pandas as pd
import numpy as np
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, KFold, cross_validate
from sklearn.feature_selection import mutual_info_regression,SelectKBest 
from sklearn.ensemble import RandomForestRegressor
from skfeature.function.similarity_based import fisher_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
#import dataset
df = pd.read_csv('/home/jupyter-17523142/Rama/Dataset/dataset_rama.csv')
X = df.drop(['No', 'Mango Cultivars', 'Vit C (mg/100g)', 'TA (mg/100g)', 'SSC (oBrix)', 'label'], axis = 1)
y_vitc = df.loc[:, 'Vit C (mg/100g)']

# separate dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(
    X, y_vitc, test_size = 0.3, random_state=0)

# %% [markdown]
# # Seleksi Fitur Fisher Score (k=300)

# %%
# %%time

#cari ranking setiap fitur berdasarkan fisher score
fisher_score = fisher_score.fisher_score(x_train.to_numpy(), y_train.to_numpy())

fisher_score
# Out:
# /home/jupyter-17523142/.local/lib/python3.7/site-packages/skfeature/function/similarity_based/fisher_score.py:59: RuntimeWarning: divide by zero encountered in true_divide
#   score = 1.0 / lap_score - 1
# CPU times: user 5.81 s, sys: 236 ms, total: 6.04 s
# Wall time: 344 ms
# array([ 778, 1022, 1031, ..., 1216, 1218,    0])

# %%
# Ascending
# bikin dataframe buat nyimpan fitur beserta rankingnya
fisher_ranking = pd.DataFrame(fisher_score)
features = pd.DataFrame(x_train.columns)
fisher_ranking = pd.concat([features,fisher_ranking],axis=1)

# Assign the column name
fisher_ranking.columns = ["Features","Fisher_Ranking"]

# Print features score
print(fisher_ranking.nsmallest(300,columns="Fisher_Ranking"))
# Out:
#      Features  Fisher_Ranking
# 1556   2500.2               0
# 260    1111.3               1
# 1188   1845.4               2
# 1406   2184.3               3
# 1189   1846.7               4
# ...       ...             ...
# 1493     2357             295
# 802    1447.6             296
# 801    1446.8             297
# 800      1446             298
# 798    1444.4             299
#
# [300 rows x 2 columns]

# %% [markdown]
# # Seleksi Fitur Backward Elimination dengan Linear Regression

# %%
x_train_selected = x_train[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:300, 0]]
x_test_selected = x_test[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:300, 0]]

# %%
x_train_selected
# Out:
#        2500.2    1111.3    1845.4    2184.3    1846.7      1852    1853.3  \
# 16   1.428625  0.438341  0.907775  1.097736  0.908989  0.921439  0.924654
# 51   1.611099  0.391662  1.065262  1.307243  1.067778  1.085994  1.091106
# 183  1.533183  0.497537  1.140941  1.305443  1.142446  1.155736  1.159088
# 145  1.428271  0.501907  1.090478  1.247814  1.091900  1.103762  1.106702
# 40   1.581424  0.339756  0.950444  1.214149  0.952297  0.968828  0.973166
# ..        ...       ...       ...       ...       ...       ...       ...
# 103  1.515658  0.476264  1.048784  1.238116  1.050575  1.064826  1.068715
# 67   1.516333  0.407174  1.014395  1.228384  1.016328  1.032534  1.036883
# 117  1.609544  0.426150  1.178860  1.404545  1.181145  1.199104  1.204185
# 47   1.591581  0.386672  1.062860  1.298707  1.065343  1.083832  1.089076
# 172  1.481630  0.424956  1.027595  1.214546  1.029577  1.044414  1.048378
#
#        1857.3    1863.9    1838.8  ...    1451.7    1450.9    1450.1  \
# 16   0.938583  0.971858  0.899052  ...  1.108341  1.108181  1.108373
# 51   1.112092  1.160458  1.052971  ...  1.356351  1.356063  1.356032
# 183  1.173587  1.206242  1.131616  ...  1.325683  1.325006  1.324760
# 145  1.119947  1.149629  1.082253  ...  1.253276  1.253272  1.253152
# 40   0.992849  1.039250  0.939128  ...  1.248552  1.248345  1.248367
# ..        ...       ...       ...  ...       ...       ...       ...
# 103  1.084751  1.121644  1.038848  ...  1.272931  1.272609  1.272558
# 67   1.054946  1.096734  1.003201  ...  1.258628  1.258800  1.259068
# 117  1.224251  1.269758  1.166576  ...  1.428554  1.428430  1.428178
# 47   1.109692  1.158657  1.050109  ...  1.354656  1.354440  1.354414
# 172  1.065207  1.103568  1.017202  ...  1.249222  1.248642  1.248308
#
#        2359.2    1448.5      2357    1447.6    1446.8      1446    1444.4
# 16   1.256366  1.108033  1.255772  1.107926  1.107721  1.107372  1.106641
# 51   1.467247  1.356365  1.465697  1.356000  1.355492  1.354792  1.354059
# 183  1.429789  1.324391  1.429389  1.324223  1.323797  1.323525  1.323314
# 145  1.347394  1.253142  1.346965  1.252922  1.252735  1.252549  1.251983
# 40   1.424007  1.248150  1.422121  1.247726  1.247627  1.247304  1.246680
# ..        ...       ...       ...       ...       ...       ...       ...
# 103  1.378025  1.272289  1.376241  1.272051  1.271575  1.271002  1.270537
# 67   1.378647  1.258452  1.377451  1.258343  1.258136  1.257725  1.257308
# 117  1.524956  1.428004  1.523609  1.427889  1.427436  1.427210  1.427226
# 47   1.454723  1.353886  1.452482  1.353804  1.353888  1.353531  1.353050
# 172  1.355493  1.248350  1.353979  1.247937  1.247684  1.247314  1.246818
#
# [130 rows x 300 columns]

# %%
# calling the Linear Regression model
lr_model = LinearRegression()
sfs = sfs(lr_model, k_features=20, forward=False, verbose=2, scoring='neg_root_mean_squared_error', n_jobs=-1)

# %%
# %%time

sfs = sfs.fit(x_train_selected, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 292 out of 300 | elapsed:    7.9s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    7.9s finished
#
# [2022-07-15 08:07:58] Features: 299/20 -- score: -3509628.81994543[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 290 out of 299 | elapsed:    1.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 299 out of 299 | elapsed:    1.4s finished
#
# [2022-07-15 08:07:59] Features: 298/20 -- score: -2486034.5419186438[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 289 out of 298 | elapsed:    1.8s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 298 out of 298 | elapsed:    1.8s finished
#
# [2022-07-15 08:08:01] Features: 297/20 -- score: -3518262.5289049298[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 287 out of 297 | elapsed:    2.0s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 297 out of 297 | elapsed:    2.0s finished
#
# [2022-07-15 08:08:03] Features: 296/20 -- score: -3883637.047829633[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 286 out of 296 | elapsed:    2.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:    2.1s finished
#
# [2022-07-15 08:08:05] Features: 295/20 -- score: -2274561.456853988[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 284 out of 295 | elapsed:    1.9s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 295 out of 295 | elapsed:    1.9s finished
#
# [2022-07-15 08:08:07] Features: 294/20 -- score: -3722165.3128846525[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 283 out of 294 | elapsed:    2.2s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 294 out of 294 | elapsed:    2.2s finished
#
# [2022-07-15 08:08:09] Features: 293/20 -- score: -2907944.3941384293[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 281 out of 293 | elapsed:    2.5s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 293 out of 293 | elapsed:    2.5s finished
#
# [2022-07-15 08:08:12] Features: 292/20 -- score: -3080495.4678825894[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 280 out of 292 | elapsed:    2.7s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:    2.7s finished
#
# [2022-07-15 08:08:14] Features: 291/20 -- score: -3527716.5013596565[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 278 out of 291 | elapsed:    2.7s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 291 out of 291 | elapsed:    2.7s finished
#
# [2022-07-15 08:08:17] Features: 290/20 -- score: -1750869.0032118738[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 277 out of 290 | elapsed:    2.7s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 290 out of 290 | elapsed:    2.7s finished
#
# [2022-07-15 08:08:20] Features: 289/20 -- score: -2013875.656738565[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 275 out of 289 | elapsed:    3.2s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 289 out of 289 | elapsed:    3.2s finished
#
# [2022-07-15 08:08:23] Features: 288/20 -- score: -3843716.2855239855[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 274 out of 288 | elapsed:    3.0s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 288 out of 288 | elapsed:    3.1s finished
#
# [2022-07-15 08:08:26] Features: 287/20 -- score: -3673043.311368338[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 272 out of 287 | elapsed:    3.4s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 287 out of 287 | elapsed:    3.4s finished
#
# [2022-07-15 08:08:30] Features: 286/20 -- score: -3446208.9813470244[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 271 out of 286 | elapsed:    3.5s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 286 out of 286 | elapsed:    3.5s finished
#
# [2022-07-15 08:08:33] Features: 285/20 -- score: -4424857.728305558[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 269 out of 285 | elapsed:    3.7s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 285 out of 285 | elapsed:    3.7s finished
#
# [2022-07-15 08:08:37] Features: 284/20 -- score: -2435911.4313047845[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 268 out of 284 | elapsed:    3.1s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 284 out of 284 | elapsed:    3.1s finished
#
# [2022-07-15 08:08:40] Features: 283/20 -- score: -3452120.756072141[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 266 out of 283 | elapsed:    3.8s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 283 out of 283 | elapsed:    3.8s finished
#
# [2022-07-15 08:08:44] Features: 282/20 -- score: -2799306.186394996[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 265 out of 282 | elapsed:    3.7s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 282 out of 282 | elapsed:    3.8s finished
#
# [2022-07-15 08:08:48] Features: 281/20 -- score: -3836054.7611433654[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 263 out of 281 | elapsed:    3.7s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 281 out of 281 | elapsed:    3.7s finished
#
# [2022-07-15 08:08:51] Features: 280/20 -- score: -3508373.9802816273[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 262 out of 280 | elapsed:    3.9s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 280 out of 280 | elapsed:    3.9s finished
#
# [2022-07-15 08:08:55] Features: 279/20 -- score: -3142482.517690839[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 260 out of 279 | elapsed:    4.2s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 279 out of 279 | elapsed:    4.2s finished
#
# [2022-07-15 08:09:00] Features: 278/20 -- score: -3114126.69106019[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 259 out of 278 | elapsed:    4.2s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 278 out of 278 | elapsed:    4.2s finished
#
# [2022-07-15 08:09:04] Features: 277/20 -- score: -3257619.772586497[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 257 out of 277 | elapsed:    4.2s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 277 out of 277 | elapsed:    4.2s finished
#
# [2022-07-15 08:09:08] Features: 276/20 -- score: -3165072.4057578114[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 256 out of 276 | elapsed:    4.2s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 276 out of 276 | elapsed:    4.2s finished
#
# [2022-07-15 08:09:12] Features: 275/20 -- score: -4007656.856451121[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 254 out of 275 | elapsed:    4.0s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 275 out of 275 | elapsed:    4.0s finished
#
# [2022-07-15 08:09:16] Features: 274/20 -- score: -2018685.2566797726[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 253 out of 274 | elapsed:    4.6s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 274 out of 274 | elapsed:    4.6s finished
#
# [2022-07-15 08:09:21] Features: 273/20 -- score: -2631736.60309861[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 251 out of 273 | elapsed:    4.4s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 273 out of 273 | elapsed:    4.4s finished
#
# [2022-07-15 08:09:25] Features: 272/20 -- score: -3102601.7901183413[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 250 out of 272 | elapsed:    4.4s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 272 out of 272 | elapsed:    4.4s finished
#
# [2022-07-15 08:09:30] Features: 271/20 -- score: -2600415.269445195[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 248 out of 271 | elapsed:    4.6s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 271 out of 271 | elapsed:    4.6s finished
#
# [2022-07-15 08:09:34] Features: 270/20 -- score: -3712860.9798268126[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 247 out of 270 | elapsed:    4.5s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 270 out of 270 | elapsed:    4.5s finished
#
# [2022-07-15 08:09:39] Features: 269/20 -- score: -2070469.932936461[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 245 out of 269 | elapsed:    4.5s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 269 out of 269 | elapsed:    4.5s finished
#
# [2022-07-15 08:09:44] Features: 268/20 -- score: -3929473.9056002693[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 244 out of 268 | elapsed:    5.0s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 268 out of 268 | elapsed:    5.0s finished
#
# [2022-07-15 08:09:49] Features: 267/20 -- score: -2676414.0556828086[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 242 out of 267 | elapsed:    4.8s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 267 out of 267 | elapsed:    4.9s finished
#
# [2022-07-15 08:09:53] Features: 266/20 -- score: -1184476.9827565644[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 241 out of 266 | elapsed:    5.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 266 out of 266 | elapsed:    5.3s finished
#
# [2022-07-15 08:09:59] Features: 265/20 -- score: -3458395.1580962157[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 239 out of 265 | elapsed:    5.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 265 out of 265 | elapsed:    5.5s finished
#
# [2022-07-15 08:10:04] Features: 264/20 -- score: -2736643.8108409317[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 238 out of 264 | elapsed:    5.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 264 out of 264 | elapsed:    5.4s finished
#
# [2022-07-15 08:10:10] Features: 263/20 -- score: -2872073.2279177755[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 236 out of 263 | elapsed:    5.2s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 263 out of 263 | elapsed:    5.3s finished
#
# [2022-07-15 08:10:15] Features: 262/20 -- score: -3045665.3715004823[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 235 out of 262 | elapsed:    5.3s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 262 out of 262 | elapsed:    5.3s finished
#
# [2022-07-15 08:10:20] Features: 261/20 -- score: -3474339.788985134[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 233 out of 261 | elapsed:    5.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 261 out of 261 | elapsed:    5.4s finished
#
# [2022-07-15 08:10:26] Features: 260/20 -- score: -2696490.0505565912[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 232 out of 260 | elapsed:    5.5s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 260 out of 260 | elapsed:    5.5s finished
#
# [2022-07-15 08:10:31] Features: 259/20 -- score: -3428340.2879729094[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 230 out of 259 | elapsed:    5.4s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 259 out of 259 | elapsed:    5.4s finished
#
# [2022-07-15 08:10:37] Features: 258/20 -- score: -2455430.932627577[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 229 out of 258 | elapsed:    5.5s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 258 out of 258 | elapsed:    5.5s finished
#
# [2022-07-15 08:10:42] Features: 257/20 -- score: -3898997.447273647[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 227 out of 257 | elapsed:    5.8s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 257 out of 257 | elapsed:    5.9s finished
#
# [2022-07-15 08:10:48] Features: 256/20 -- score: -3054002.2149887015[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 226 out of 256 | elapsed:    5.6s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 256 out of 256 | elapsed:    5.8s finished
#
# [2022-07-15 08:10:54] Features: 255/20 -- score: -2717084.567048662[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 224 out of 255 | elapsed:    5.1s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 255 out of 255 | elapsed:    5.8s finished
#
# [2022-07-15 08:11:00] Features: 254/20 -- score: -1857174.475062263[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 223 out of 254 | elapsed:    5.7s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 254 out of 254 | elapsed:    6.4s finished
#
# [2022-07-15 08:11:06] Features: 253/20 -- score: -2455966.643309978[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 221 out of 253 | elapsed:    5.8s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 253 out of 253 | elapsed:    6.6s finished
#
# [2022-07-15 08:11:13] Features: 252/20 -- score: -3561511.832684937[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 220 out of 252 | elapsed:    5.7s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 252 out of 252 | elapsed:    6.5s finished
#
# [2022-07-15 08:11:19] Features: 251/20 -- score: -3431889.1262508584[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 218 out of 251 | elapsed:    5.8s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 251 out of 251 | elapsed:    6.6s finished
#
# [2022-07-15 08:11:26] Features: 250/20 -- score: -1562721.974580702[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 217 out of 250 | elapsed:    5.9s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:    6.4s finished
#
# [2022-07-15 08:11:32] Features: 249/20 -- score: -2799982.6642354527[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 215 out of 249 | elapsed:    5.3s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 249 out of 249 | elapsed:    6.1s finished
#
# [2022-07-15 08:11:38] Features: 248/20 -- score: -3289155.654703751[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 214 out of 248 | elapsed:    5.5s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 248 out of 248 | elapsed:    6.3s finished
#
# [2022-07-15 08:11:45] Features: 247/20 -- score: -2462810.618951713[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 212 out of 247 | elapsed:    5.6s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 247 out of 247 | elapsed:    6.5s finished
#
# [2022-07-15 08:11:51] Features: 246/20 -- score: -2011283.4301332235[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 211 out of 246 | elapsed:    5.8s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 246 out of 246 | elapsed:    6.7s finished
#
# [2022-07-15 08:11:58] Features: 245/20 -- score: -2149107.1618530396[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 209 out of 245 | elapsed:    5.6s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 245 out of 245 | elapsed:    6.3s finished
#
# [2022-07-15 08:12:04] Features: 244/20 -- score: -2373449.293174043[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 208 out of 244 | elapsed:    5.8s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 244 out of 244 | elapsed:    6.6s finished
#
# [2022-07-15 08:12:11] Features: 243/20 -- score: -3094418.033899747[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 206 out of 243 | elapsed:    5.6s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 243 out of 243 | elapsed:    6.7s finished
#
# [2022-07-15 08:12:17] Features: 242/20 -- score: -2384732.9856489776[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 205 out of 242 | elapsed:    5.9s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 242 out of 242 | elapsed:    6.5s finished
#
# [2022-07-15 08:12:24] Features: 241/20 -- score: -2215705.144414509[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 203 out of 241 | elapsed:    6.2s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 241 out of 241 | elapsed:    6.6s finished
#
# [2022-07-15 08:12:31] Features: 240/20 -- score: -3716334.7719596564[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 202 out of 240 | elapsed:    5.4s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed:    6.4s finished
#
# [2022-07-15 08:12:37] Features: 239/20 -- score: -2145486.754535[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 200 out of 239 | elapsed:    5.6s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 239 out of 239 | elapsed:    6.7s finished
#
# [2022-07-15 08:12:44] Features: 238/20 -- score: -2793063.1024079705[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 199 out of 238 | elapsed:    5.7s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 238 out of 238 | elapsed:    6.8s finished
#
# [2022-07-15 08:12:51] Features: 237/20 -- score: -3959239.7742422163[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 197 out of 237 | elapsed:    5.9s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 237 out of 237 | elapsed:    7.1s finished
#
# [2022-07-15 08:12:58] Features: 236/20 -- score: -3513365.2839348107[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 196 out of 236 | elapsed:    5.6s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 236 out of 236 | elapsed:    6.8s finished
#
# [2022-07-15 08:13:04] Features: 235/20 -- score: -2588634.8393068635[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 194 out of 235 | elapsed:    5.6s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 235 out of 235 | elapsed:    6.8s finished
#
# [2022-07-15 08:13:11] Features: 234/20 -- score: -2911103.627215082[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 193 out of 234 | elapsed:    5.5s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 234 out of 234 | elapsed:    6.6s finished
#
# [2022-07-15 08:13:18] Features: 233/20 -- score: -2741420.126587528[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 191 out of 233 | elapsed:    5.5s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 233 out of 233 | elapsed:    6.7s finished
#
# [2022-07-15 08:13:25] Features: 232/20 -- score: -1770755.2683938518[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 190 out of 232 | elapsed:    5.6s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 232 out of 232 | elapsed:    6.8s finished
#
# [2022-07-15 08:13:31] Features: 231/20 -- score: -3784699.460892177[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 188 out of 231 | elapsed:    5.5s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 231 out of 231 | elapsed:    6.8s finished
#
# [2022-07-15 08:13:38] Features: 230/20 -- score: -3617052.6501814066[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 187 out of 230 | elapsed:    5.7s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 230 out of 230 | elapsed:    6.9s finished
#
# [2022-07-15 08:13:45] Features: 229/20 -- score: -2111819.640061946[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 185 out of 229 | elapsed:    5.6s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 229 out of 229 | elapsed:    6.9s finished
#
# [2022-07-15 08:13:52] Features: 228/20 -- score: -4246353.978739442[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 184 out of 228 | elapsed:    5.6s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 228 out of 228 | elapsed:    6.8s finished
#
# [2022-07-15 08:13:59] Features: 227/20 -- score: -1307159.5213252602[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 182 out of 227 | elapsed:    5.7s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done 227 out of 227 | elapsed:    7.1s finished
#
# [2022-07-15 08:14:06] Features: 226/20 -- score: -2578175.0714045363[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 181 out of 226 | elapsed:    5.8s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done 226 out of 226 | elapsed:    7.2s finished
#
# [2022-07-15 08:14:13] Features: 225/20 -- score: -1834890.8613076352[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 179 out of 225 | elapsed:    5.8s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 225 out of 225 | elapsed:    7.3s finished
#
# [2022-07-15 08:14:20] Features: 224/20 -- score: -3306830.9196190834[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 178 out of 224 | elapsed:    5.9s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 224 out of 224 | elapsed:    7.4s finished
#
# [2022-07-15 08:14:28] Features: 223/20 -- score: -3159588.2074587857[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 176 out of 223 | elapsed:    5.9s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 223 out of 223 | elapsed:    7.4s finished
#
# [2022-07-15 08:14:35] Features: 222/20 -- score: -2516164.5829580636[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 175 out of 222 | elapsed:    5.8s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 222 out of 222 | elapsed:    7.3s finished
#
# [2022-07-15 08:14:43] Features: 221/20 -- score: -3801173.0205821553[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 173 out of 221 | elapsed:    5.8s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 221 out of 221 | elapsed:    7.4s finished
#
# [2022-07-15 08:14:50] Features: 220/20 -- score: -2944057.654834083[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 172 out of 220 | elapsed:    5.8s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 220 out of 220 | elapsed:    7.3s finished
#
# [2022-07-15 08:14:57] Features: 219/20 -- score: -4225741.289949248[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 170 out of 219 | elapsed:    5.8s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 219 out of 219 | elapsed:    7.5s finished
#
# [2022-07-15 08:15:05] Features: 218/20 -- score: -3644070.097460903[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 169 out of 218 | elapsed:    5.9s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done 218 out of 218 | elapsed:    7.6s finished
#
# [2022-07-15 08:15:12] Features: 217/20 -- score: -3163288.308801892[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 167 out of 217 | elapsed:    5.9s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 217 out of 217 | elapsed:    7.6s finished
#
# [2022-07-15 08:15:20] Features: 216/20 -- score: -3665999.306487914[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 166 out of 216 | elapsed:    5.8s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 216 out of 216 | elapsed:    7.6s finished
#
# [2022-07-15 08:15:28] Features: 215/20 -- score: -3059427.3130812785[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 164 out of 215 | elapsed:    6.1s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 215 out of 215 | elapsed:    7.9s finished
#
# [2022-07-15 08:15:36] Features: 214/20 -- score: -3933343.521266263[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 163 out of 214 | elapsed:    6.1s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 214 out of 214 | elapsed:    7.9s finished
#
# [2022-07-15 08:15:44] Features: 213/20 -- score: -2529679.86059573[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 161 out of 213 | elapsed:    6.0s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 213 out of 213 | elapsed:    7.9s finished
#
# [2022-07-15 08:15:51] Features: 212/20 -- score: -2223782.000506657[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 160 out of 212 | elapsed:    5.8s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 212 out of 212 | elapsed:    7.5s finished
#
# [2022-07-15 08:15:59] Features: 211/20 -- score: -3085392.625269088[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 158 out of 211 | elapsed:    5.5s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 211 out of 211 | elapsed:    7.2s finished
#
# [2022-07-15 08:16:06] Features: 210/20 -- score: -2609878.895106247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 157 out of 210 | elapsed:    5.5s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 210 out of 210 | elapsed:    7.4s finished
#
# [2022-07-15 08:16:14] Features: 209/20 -- score: -2316909.549837013[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 155 out of 209 | elapsed:    5.6s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 209 out of 209 | elapsed:    7.6s finished
#
# [2022-07-15 08:16:21] Features: 208/20 -- score: -5985813.3908796515[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 154 out of 208 | elapsed:    6.0s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done 208 out of 208 | elapsed:    8.0s finished
#
# [2022-07-15 08:16:29] Features: 207/20 -- score: -2850397.8842618493[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 152 out of 207 | elapsed:    5.8s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done 207 out of 207 | elapsed:    7.9s finished
#
# [2022-07-15 08:16:37] Features: 206/20 -- score: -4320770.116246821[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 151 out of 206 | elapsed:    5.9s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done 206 out of 206 | elapsed:    8.0s finished
#
# [2022-07-15 08:16:45] Features: 205/20 -- score: -6006688.473822598[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 149 out of 205 | elapsed:    6.0s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 205 out of 205 | elapsed:    8.1s finished
#
# [2022-07-15 08:16:53] Features: 204/20 -- score: -6981977.874188928[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 148 out of 204 | elapsed:    5.9s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 204 out of 204 | elapsed:    8.1s finished
#
# [2022-07-15 08:17:02] Features: 203/20 -- score: -3946461.5591105083[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 146 out of 203 | elapsed:    5.9s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 203 out of 203 | elapsed:    8.1s finished
#
# [2022-07-15 08:17:10] Features: 202/20 -- score: -4560658.560708205[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 145 out of 202 | elapsed:    5.9s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 202 out of 202 | elapsed:    8.1s finished
#
# [2022-07-15 08:17:18] Features: 201/20 -- score: -4422019.99168815[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 143 out of 201 | elapsed:    5.8s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 201 out of 201 | elapsed:    8.1s finished
#
# [2022-07-15 08:17:26] Features: 200/20 -- score: -17193085.725683987[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 142 out of 200 | elapsed:    6.0s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    8.4s finished
#
# [2022-07-15 08:17:34] Features: 199/20 -- score: -12510370.100589393[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 140 out of 199 | elapsed:    5.9s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done 199 out of 199 | elapsed:    8.2s finished
#
# [2022-07-15 08:17:42] Features: 198/20 -- score: -13468988.16938417[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 139 out of 198 | elapsed:    5.4s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 198 out of 198 | elapsed:    7.6s finished
#
# [2022-07-15 08:17:50] Features: 197/20 -- score: -20591008.57604313[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 137 out of 197 | elapsed:    5.4s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 197 out of 197 | elapsed:    7.8s finished
#
# [2022-07-15 08:17:58] Features: 196/20 -- score: -19691163.368691675[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 136 out of 196 | elapsed:    5.6s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done 196 out of 196 | elapsed:    8.0s finished
#
# [2022-07-15 08:18:06] Features: 195/20 -- score: -20619051.404394068[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 134 out of 195 | elapsed:    5.5s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done 195 out of 195 | elapsed:    7.9s finished
#
# [2022-07-15 08:18:14] Features: 194/20 -- score: -23361456.461452056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 133 out of 194 | elapsed:    5.5s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done 194 out of 194 | elapsed:    8.0s finished
#
# [2022-07-15 08:18:22] Features: 193/20 -- score: -16148950.4964466[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 131 out of 193 | elapsed:    5.5s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 193 out of 193 | elapsed:    8.1s finished
#
# [2022-07-15 08:18:30] Features: 192/20 -- score: -22224181.65178422[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 130 out of 192 | elapsed:    5.8s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 192 out of 192 | elapsed:    8.7s finished
#
# [2022-07-15 08:18:39] Features: 191/20 -- score: -15719374.346351018[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 128 out of 191 | elapsed:    5.6s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 191 out of 191 | elapsed:    8.2s finished
#
# [2022-07-15 08:18:47] Features: 190/20 -- score: -17008862.940664303[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 127 out of 190 | elapsed:    5.4s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done 190 out of 190 | elapsed:    7.9s finished
#
# [2022-07-15 08:18:55] Features: 189/20 -- score: -17648314.632818427[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 125 out of 189 | elapsed:    5.4s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 189 out of 189 | elapsed:    8.1s finished
#
# [2022-07-15 08:19:03] Features: 188/20 -- score: -17709209.66328939[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 124 out of 188 | elapsed:    5.3s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 188 out of 188 | elapsed:    7.9s finished
#
# [2022-07-15 08:19:11] Features: 187/20 -- score: -28146124.110140096[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of 187 | elapsed:    1.7s remaining:    9.6s
# [Parallel(n_jobs=-1)]: Done 122 out of 187 | elapsed:    5.2s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 187 out of 187 | elapsed:    7.9s finished
#
# [2022-07-15 08:19:19] Features: 186/20 -- score: -22183052.961107932[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 121 out of 186 | elapsed:    5.4s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 186 out of 186 | elapsed:    8.2s finished
#
# [2022-07-15 08:19:27] Features: 185/20 -- score: -16807798.165765576[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 119 out of 185 | elapsed:    5.6s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done 185 out of 185 | elapsed:    8.5s finished
#
# [2022-07-15 08:19:36] Features: 184/20 -- score: -14978998.973165762[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 118 out of 184 | elapsed:    5.4s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 184 out of 184 | elapsed:    8.3s finished
#
# [2022-07-15 08:19:44] Features: 183/20 -- score: -24663648.895528346[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 116 out of 183 | elapsed:    5.1s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 183 out of 183 | elapsed:    7.9s finished
#
# [2022-07-15 08:19:52] Features: 182/20 -- score: -23155005.285308413[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 115 out of 182 | elapsed:    5.0s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 182 out of 182 | elapsed:    7.9s finished
#
# [2022-07-15 08:20:00] Features: 181/20 -- score: -20335868.022345223[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 113 out of 181 | elapsed:    5.0s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 181 out of 181 | elapsed:    7.9s finished
#
# [2022-07-15 08:20:08] Features: 180/20 -- score: -12833226.370250273[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 112 out of 180 | elapsed:    5.0s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:    7.9s finished
#
# [2022-07-15 08:20:16] Features: 179/20 -- score: -23046672.33562277[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 110 out of 179 | elapsed:    5.0s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done 179 out of 179 | elapsed:    7.9s finished
#
# [2022-07-15 08:20:23] Features: 178/20 -- score: -19631529.1777594[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 109 out of 178 | elapsed:    5.2s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 178 out of 178 | elapsed:    8.2s finished
#
# [2022-07-15 08:20:32] Features: 177/20 -- score: -9089781.37754831[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 107 out of 177 | elapsed:    4.8s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done 177 out of 177 | elapsed:    7.9s finished
#
# [2022-07-15 08:20:40] Features: 176/20 -- score: -14518617.876020342[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 106 out of 176 | elapsed:    4.9s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 176 out of 176 | elapsed:    8.0s finished
#
# [2022-07-15 08:20:48] Features: 175/20 -- score: -25343343.166089036[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 104 out of 175 | elapsed:    4.7s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 175 out of 175 | elapsed:    7.8s finished
#
# [2022-07-15 08:20:55] Features: 174/20 -- score: -15935467.756009523[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 103 out of 174 | elapsed:    4.7s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 174 out of 174 | elapsed:    7.9s finished
#
# [2022-07-15 08:21:03] Features: 173/20 -- score: -21363445.02563889[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 101 out of 173 | elapsed:    4.6s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 173 out of 173 | elapsed:    7.9s finished
#
# [2022-07-15 08:21:11] Features: 172/20 -- score: -12676473.634070527[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 100 out of 172 | elapsed:    5.2s remaining:    3.8s
# [Parallel(n_jobs=-1)]: Done 172 out of 172 | elapsed:    8.5s finished
#
# [2022-07-15 08:21:20] Features: 171/20 -- score: -20177494.051285423[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done  98 out of 171 | elapsed:    5.0s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 171 out of 171 | elapsed:    8.3s finished
#
# [2022-07-15 08:21:28] Features: 170/20 -- score: -14835027.645490697[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done  97 out of 170 | elapsed:    4.6s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done 170 out of 170 | elapsed:    7.9s finished
#
# [2022-07-15 08:21:36] Features: 169/20 -- score: -27033107.15840293[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  95 out of 169 | elapsed:    4.5s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done 169 out of 169 | elapsed:    7.8s finished
#
# [2022-07-15 08:21:44] Features: 168/20 -- score: -21107194.791475095[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  94 out of 168 | elapsed:    4.7s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 168 out of 168 | elapsed:    8.1s finished
#
# [2022-07-15 08:21:52] Features: 167/20 -- score: -30038262.670684446[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# ...
# [Parallel(n_jobs=-1)]: Done   4 out of  64 | elapsed:    0.3s remaining:    5.0s
# [Parallel(n_jobs=-1)]: Done  37 out of  64 | elapsed:    2.6s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done  64 out of  64 | elapsed:    4.4s finished
#
# [2022-07-15 08:33:28] Features: 63/20 -- score: -16.16538661499962[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  63 | elapsed:    2.4s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done  63 out of  63 | elapsed:    4.5s finished
#
# [2022-07-15 08:33:33] Features: 62/20 -- score: -15.877751495290514[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  62 | elapsed:    2.1s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  62 out of  62 | elapsed:    4.1s finished
#
# [2022-07-15 08:33:37] Features: 61/20 -- score: -15.490915648402318[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  26 out of  61 | elapsed:    1.8s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done  57 out of  61 | elapsed:    3.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  61 out of  61 | elapsed:    4.1s finished
#
# [2022-07-15 08:33:41] Features: 60/20 -- score: -15.218017369198218[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of  60 | elapsed:    1.8s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done  56 out of  60 | elapsed:    3.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done  60 out of  60 | elapsed:    4.1s finished
#
# [2022-07-15 08:33:45] Features: 59/20 -- score: -14.89758488882553[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  59 | elapsed:    1.4s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  50 out of  59 | elapsed:    3.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  59 out of  59 | elapsed:    4.0s finished
#
# [2022-07-15 08:33:49] Features: 58/20 -- score: -14.579989732689304[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  58 | elapsed:    1.3s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done  49 out of  58 | elapsed:    3.3s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  58 out of  58 | elapsed:    3.9s finished
#
# [2022-07-15 08:33:53] Features: 57/20 -- score: -13.95938135541355[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  57 | elapsed:    1.0s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done  43 out of  57 | elapsed:    2.9s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  57 out of  57 | elapsed:    3.8s finished
#
# [2022-07-15 08:33:57] Features: 56/20 -- score: -13.762845687585786[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of  56 | elapsed:    0.9s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  42 out of  56 | elapsed:    2.9s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  56 out of  56 | elapsed:    3.8s finished
#
# [2022-07-15 08:34:01] Features: 55/20 -- score: -13.33673225175249[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  55 | elapsed:    0.6s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done  36 out of  55 | elapsed:    2.5s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  55 | elapsed:    3.8s finished
#
# [2022-07-15 08:34:04] Features: 54/20 -- score: -13.057083264066183[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  54 | elapsed:    0.6s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done  35 out of  54 | elapsed:    2.5s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  54 out of  54 | elapsed:    3.8s finished
#
# [2022-07-15 08:34:08] Features: 53/20 -- score: -12.886088248627782[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  53 | elapsed:    0.2s remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done  29 out of  53 | elapsed:    2.0s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  53 out of  53 | elapsed:    3.6s finished
#
# [2022-07-15 08:34:12] Features: 52/20 -- score: -12.562866277213365[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  52 | elapsed:    2.0s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  52 out of  52 | elapsed:    3.5s finished
#
# [2022-07-15 08:34:15] Features: 51/20 -- score: -12.417699965833185[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of  51 | elapsed:    1.6s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  48 out of  51 | elapsed:    3.4s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  51 out of  51 | elapsed:    3.6s finished
#
# [2022-07-15 08:34:19] Features: 50/20 -- score: -12.320085021807163[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  21 out of  50 | elapsed:    1.5s remaining:    2.1s
# [Parallel(n_jobs=-1)]: Done  47 out of  50 | elapsed:    3.3s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  50 out of  50 | elapsed:    3.5s finished
#
# [2022-07-15 08:34:23] Features: 49/20 -- score: -12.225778625891289[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  49 | elapsed:    1.1s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done  40 out of  49 | elapsed:    2.8s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  49 out of  49 | elapsed:    3.4s finished
#
# [2022-07-15 08:34:26] Features: 48/20 -- score: -12.116555548898651[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of  48 | elapsed:    1.0s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done  39 out of  48 | elapsed:    2.8s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  48 out of  48 | elapsed:    3.4s finished
#
# [2022-07-15 08:34:29] Features: 47/20 -- score: -12.06052685797633[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  47 | elapsed:    0.6s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done  32 out of  47 | elapsed:    2.3s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  47 out of  47 | elapsed:    3.3s finished
#
# [2022-07-15 08:34:33] Features: 46/20 -- score: -12.056398471503332[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  46 | elapsed:    0.6s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done  31 out of  46 | elapsed:    2.2s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  46 out of  46 | elapsed:    3.3s finished
#
# [2022-07-15 08:34:36] Features: 45/20 -- score: -11.96281006497286[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 out of  45 | elapsed:    1.8s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done  45 out of  45 | elapsed:    3.2s finished
#
# [2022-07-15 08:34:39] Features: 44/20 -- score: -11.889591716943025[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  44 | elapsed:    1.7s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done  44 out of  44 | elapsed:    3.1s finished
#
# [2022-07-15 08:34:42] Features: 43/20 -- score: -11.838118513150715[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  43 | elapsed:    1.2s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  38 out of  43 | elapsed:    2.7s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  43 out of  43 | elapsed:    3.1s finished
#
# [2022-07-15 08:34:45] Features: 42/20 -- score: -11.818077577370865[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  42 | elapsed:    1.1s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  37 out of  42 | elapsed:    2.7s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  42 out of  42 | elapsed:    3.0s finished
#
# [2022-07-15 08:34:48] Features: 41/20 -- score: -11.83263775051292[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  41 | elapsed:    0.6s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done  29 out of  41 | elapsed:    2.1s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  41 out of  41 | elapsed:    2.9s finished
#
# [2022-07-15 08:34:51] Features: 40/20 -- score: -11.773494435875577[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   1 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done   7 out of  40 | elapsed:    0.6s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done  28 out of  40 | elapsed:    2.1s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done  40 out of  40 | elapsed:    2.9s finished
#
# [2022-07-15 08:34:54] Features: 39/20 -- score: -11.763877189977922[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  39 | elapsed:    1.5s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  39 out of  39 | elapsed:    2.9s finished
#
# [2022-07-15 08:34:57] Features: 38/20 -- score: -11.75502083155511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  38 | elapsed:    1.4s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  38 out of  38 | elapsed:    2.8s finished
#
# [2022-07-15 08:35:00] Features: 37/20 -- score: -11.721173704895657[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  37 | elapsed:    0.9s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  30 out of  37 | elapsed:    2.3s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  37 out of  37 | elapsed:    2.7s finished
#
# [2022-07-15 08:35:03] Features: 36/20 -- score: -11.657012235532523[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  36 | elapsed:    0.8s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  29 out of  36 | elapsed:    2.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done  36 out of  36 | elapsed:    2.6s finished
#
# [2022-07-15 08:35:05] Features: 35/20 -- score: -11.665989536409807[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of  35 | elapsed:    0.2s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done  20 out of  35 | elapsed:    1.5s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:    2.6s finished
#
# [2022-07-15 08:35:08] Features: 34/20 -- score: -11.560018723324983[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  34 | elapsed:    1.5s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  34 out of  34 | elapsed:    2.5s finished
#
# [2022-07-15 08:35:11] Features: 33/20 -- score: -11.630043883307778[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of  33 | elapsed:    0.8s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done  27 out of  33 | elapsed:    2.0s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  33 out of  33 | elapsed:    2.4s finished
#
# [2022-07-15 08:35:13] Features: 32/20 -- score: -11.664804521574968[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 out of  32 | elapsed:    0.7s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done  26 out of  32 | elapsed:    1.9s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  32 out of  32 | elapsed:    2.3s finished
#
# [2022-07-15 08:35:15] Features: 31/20 -- score: -11.567403604256679[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  31 | elapsed:    1.4s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  31 out of  31 | elapsed:    2.6s finished
#
# [2022-07-15 08:35:18] Features: 30/20 -- score: -11.500587529933735[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  30 | elapsed:    1.1s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:    2.1s finished
#
# [2022-07-15 08:35:20] Features: 29/20 -- score: -11.460776977340577[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  29 | elapsed:    0.4s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done  20 out of  29 | elapsed:    1.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  29 out of  29 | elapsed:    2.0s finished
#
# [2022-07-15 08:35:22] Features: 28/20 -- score: -11.338590158982973[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  28 | elapsed:    0.3s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  19 out of  28 | elapsed:    1.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  28 out of  28 | elapsed:    2.0s finished
#
# [2022-07-15 08:35:24] Features: 27/20 -- score: -11.26395069697856[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  27 | elapsed:    0.6s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done  22 out of  27 | elapsed:    1.6s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  27 out of  27 | elapsed:    1.9s finished
#
# [2022-07-15 08:35:26] Features: 26/20 -- score: -11.196722819086315[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  26 | elapsed:    0.5s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done  21 out of  26 | elapsed:    1.5s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done  26 out of  26 | elapsed:    1.8s finished
#
# [2022-07-15 08:35:28] Features: 25/20 -- score: -11.138438864892938[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   9 out of  25 | elapsed:    0.7s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  22 out of  25 | elapsed:    1.6s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  25 out of  25 | elapsed:    1.8s finished
#
# [2022-07-15 08:35:30] Features: 24/20 -- score: -11.247426594611502[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  24 | elapsed:    0.6s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  21 out of  24 | elapsed:    1.5s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  24 out of  24 | elapsed:    1.7s finished
#
# [2022-07-15 08:35:31] Features: 23/20 -- score: -11.470834092350117[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  23 | elapsed:    0.6s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  20 out of  23 | elapsed:    1.4s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  23 out of  23 | elapsed:    1.6s finished
#
# [2022-07-15 08:35:33] Features: 22/20 -- score: -11.578931042894403[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  22 | elapsed:    0.6s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  19 out of  22 | elapsed:    1.4s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done  22 out of  22 | elapsed:    1.6s finished
#
# [2022-07-15 08:35:35] Features: 21/20 -- score: -11.628646379269494[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of  21 | elapsed:    0.4s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  16 out of  21 | elapsed:    1.2s remaining:    0.4s
# CPU times: user 27min 38s, sys: 26.9 s, total: 28min 5s
# Wall time: 27min 46s
# [Parallel(n_jobs=-1)]: Done  21 out of  21 | elapsed:    1.6s finished
#
# [2022-07-15 08:35:36] Features: 20/20 -- score: -11.839948495461165

# %%
feat_names = list(sfs.k_feature_names_)
print("Fitur yang diambil adalah: ")
print(feat_names)
len(feat_names)
# Out:
# Fitur yang diambil adalah:
# ['2500.2', '1857.3', '1768.6', '1785.6', '2000.6', '1496.1', '1455.8', '1442', '1612.4', '1623.5', '1600.5', '1621.5', '2414.1', '1615.4', '1557.2', '1578', '1678.1', '1637.9', '1632.7', '2365.6']
# 20

# %% [markdown]
# # Prediksi Linear Regression

# %%
#cross validation 10-fold
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [20]

for nfeat in n_feat:
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur Fisher Score
        x_train_selected = x_train[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]
        x_test_selected = x_test[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]

        #Create a Linear Regression
        lr_model = LinearRegression()
        
        #Train the model using the training sets
        lr_model.fit(x_train_selected, y_train)
        y_pred_lr = lr_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(lr_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Linear Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Linear data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_lr), 2))))
        print("RMSE model Linear data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_lr, squared = False), 2))))
        print("MAE model Linear data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_lr), 2))))
        print("R2 model Linear data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_lr), 2))))
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 20 fitur: 116.47
# RMSE model Linear Regression data Train dengan 20 fitur:10.79
# MAE model Linear Regression data Train dengan 20 fitur:8.63
# R2 model Linear Regression data Train dengan 20 fitur:0.39
# ----------------------------
# MSE model Linear data Test dengan 20 fitur:148.38
# RMSE model Linear data Test dengan 20 fitur:12.18
# MAE model Linear data Test dengan 20 fitur:9.62
# R2 model Linear data Test dengan 20 fitur:0.14
# ==================================================
# CPU times: user 3.94 s, sys: 104 ms, total: 4.05 s
# Wall time: 123 ms

# %% [markdown]
# # Prediksi Random Forest Regressor

# %% [markdown]
# ## 100 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [20]
n_trees = [100]

for nfeat in n_feat:
    for ntrees in n_trees:
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur Fisher Score
        x_train_selected = x_train[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]
        x_test_selected = x_test[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 20 fitur: 39.16
# RMSE model Linear Regression data Train dengan 20 fitur:6.25
# MAE model Linear Regression data Train dengan 20 fitur:4.74
# R2 model Linear Regression data Train dengan 20 fitur:0.8
# ----------------------------
# MSE model Linear data Test dengan 20 fitur:183.99
# RMSE model Linear data Test dengan 20 fitur:13.56
# MAE model Linear data Test dengan 20 fitur:10.63
# R2 model Linear data Test dengan 20 fitur:0.07
# ==================================================
# CPU times: user 5.68 s, sys: 120 ms, total: 5.8 s
# Wall time: 1.79 s

# %% [markdown]
# ## 150 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [20]
n_trees = [150]

for nfeat in n_feat:
    for ntrees in n_trees:
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur Fisher Score
        x_train_selected = x_train[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]
        x_test_selected = x_test[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 20 fitur: 38.77
# RMSE model Linear Regression data Train dengan 20 fitur:6.22
# MAE model Linear Regression data Train dengan 20 fitur:4.73
# R2 model Linear Regression data Train dengan 20 fitur:0.8
# ----------------------------
# MSE model Linear data Test dengan 20 fitur:182.81
# RMSE model Linear data Test dengan 20 fitur:13.52
# MAE model Linear data Test dengan 20 fitur:10.57
# R2 model Linear data Test dengan 20 fitur:0.06
# ==================================================
# CPU times: user 2.52 s, sys: 12 ms, total: 2.53 s
# Wall time: 2.53 s

# %% [markdown]
# ## 200 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [20]
n_trees = [200]
for nfeat in n_feat:
    for ntrees in n_trees:
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur Fisher Score
        x_train_selected = x_train[fisher_ranking.nlargest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]
        x_test_selected = x_test[fisher_ranking.nlargest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 20 fitur: 39.23
# RMSE model Linear Regression data Train dengan 20 fitur:6.26
# MAE model Linear Regression data Train dengan 20 fitur:4.77
# R2 model Linear Regression data Train dengan 20 fitur:0.8
# ----------------------------
# MSE model Linear data Test dengan 20 fitur:174.92
# RMSE model Linear data Test dengan 20 fitur:13.23
# MAE model Linear data Test dengan 20 fitur:10.53
# R2 model Linear data Test dengan 20 fitur:0.01
# ==================================================
# CPU times: user 2.86 s, sys: 19.8 ms, total: 2.88 s
# Wall time: 2.88 s
