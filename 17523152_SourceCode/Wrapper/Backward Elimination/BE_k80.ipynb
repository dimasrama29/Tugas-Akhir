# %% [markdown]
# referensi https://www.analyticsvidhya.com/blog/2021/04/forward-feature-selection-and-its-implementation/

# %%
# # instal library mlxtend
# %pip install mlxtend

# %%
# Import Library
import pandas as pd
import numpy as np
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split, KFold, cross_validate
from sklearn.feature_selection import mutual_info_regression,SelectKBest 
from sklearn.ensemble import RandomForestRegressor
from skfeature.function.similarity_based import fisher_score
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
#import dataset
df = pd.read_csv('/home/jupyter-17523142/Rama/Dataset/dataset_rama.csv')
X = df.drop(['No', 'Mango Cultivars', 'Vit C (mg/100g)', 'TA (mg/100g)', 'SSC (oBrix)', 'label'], axis = 1)
y_vitc = df.loc[:, 'Vit C (mg/100g)']

# separate dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(
    X, y_vitc, test_size = 0.3, random_state=0)

# %% [markdown]
# # Seleksi Fitur Fisher Score (k=300)

# %%
# %%time

#cari ranking setiap fitur berdasarkan fisher score
fisher_score = fisher_score.fisher_score(x_train.to_numpy(), y_train.to_numpy())

fisher_score
# Out:
# /home/jupyter-17523142/.local/lib/python3.7/site-packages/skfeature/function/similarity_based/fisher_score.py:59: RuntimeWarning: divide by zero encountered in true_divide
#   score = 1.0 / lap_score - 1
# CPU times: user 5.49 s, sys: 261 ms, total: 5.75 s
# Wall time: 411 ms
# array([ 778, 1022, 1031, ..., 1216, 1218,    0])

# %%
# Ascending
# bikin dataframe buat nyimpan fitur beserta rankingnya
fisher_ranking = pd.DataFrame(fisher_score)
features = pd.DataFrame(x_train.columns)
fisher_ranking = pd.concat([features,fisher_ranking],axis=1)

# Assign the column name
fisher_ranking.columns = ["Features","Fisher_Ranking"]

# Print features score
print(fisher_ranking.nsmallest(300,columns="Fisher_Ranking"))
# Out:
#      Features  Fisher_Ranking
# 1556   2500.2               0
# 260    1111.3               1
# 1188   1845.4               2
# 1406   2184.3               3
# 1189   1846.7               4
# ...       ...             ...
# 1493     2357             295
# 802    1447.6             296
# 801    1446.8             297
# 800      1446             298
# 798    1444.4             299
#
# [300 rows x 2 columns]

# %% [markdown]
# # Seleksi Fitur Backward Elimination dengan Linear Regression

# %%
x_train_selected = x_train[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:300, 0]]
x_test_selected = x_test[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:300, 0]]

# %%
x_train_selected
# Out:
#        2500.2    1111.3    1845.4    2184.3    1846.7      1852    1853.3  \
# 16   1.428625  0.438341  0.907775  1.097736  0.908989  0.921439  0.924654
# 51   1.611099  0.391662  1.065262  1.307243  1.067778  1.085994  1.091106
# 183  1.533183  0.497537  1.140941  1.305443  1.142446  1.155736  1.159088
# 145  1.428271  0.501907  1.090478  1.247814  1.091900  1.103762  1.106702
# 40   1.581424  0.339756  0.950444  1.214149  0.952297  0.968828  0.973166
# ..        ...       ...       ...       ...       ...       ...       ...
# 103  1.515658  0.476264  1.048784  1.238116  1.050575  1.064826  1.068715
# 67   1.516333  0.407174  1.014395  1.228384  1.016328  1.032534  1.036883
# 117  1.609544  0.426150  1.178860  1.404545  1.181145  1.199104  1.204185
# 47   1.591581  0.386672  1.062860  1.298707  1.065343  1.083832  1.089076
# 172  1.481630  0.424956  1.027595  1.214546  1.029577  1.044414  1.048378
#
#        1857.3    1863.9    1838.8  ...    1451.7    1450.9    1450.1  \
# 16   0.938583  0.971858  0.899052  ...  1.108341  1.108181  1.108373
# 51   1.112092  1.160458  1.052971  ...  1.356351  1.356063  1.356032
# 183  1.173587  1.206242  1.131616  ...  1.325683  1.325006  1.324760
# 145  1.119947  1.149629  1.082253  ...  1.253276  1.253272  1.253152
# 40   0.992849  1.039250  0.939128  ...  1.248552  1.248345  1.248367
# ..        ...       ...       ...  ...       ...       ...       ...
# 103  1.084751  1.121644  1.038848  ...  1.272931  1.272609  1.272558
# 67   1.054946  1.096734  1.003201  ...  1.258628  1.258800  1.259068
# 117  1.224251  1.269758  1.166576  ...  1.428554  1.428430  1.428178
# 47   1.109692  1.158657  1.050109  ...  1.354656  1.354440  1.354414
# 172  1.065207  1.103568  1.017202  ...  1.249222  1.248642  1.248308
#
#        2359.2    1448.5      2357    1447.6    1446.8      1446    1444.4
# 16   1.256366  1.108033  1.255772  1.107926  1.107721  1.107372  1.106641
# 51   1.467247  1.356365  1.465697  1.356000  1.355492  1.354792  1.354059
# 183  1.429789  1.324391  1.429389  1.324223  1.323797  1.323525  1.323314
# 145  1.347394  1.253142  1.346965  1.252922  1.252735  1.252549  1.251983
# 40   1.424007  1.248150  1.422121  1.247726  1.247627  1.247304  1.246680
# ..        ...       ...       ...       ...       ...       ...       ...
# 103  1.378025  1.272289  1.376241  1.272051  1.271575  1.271002  1.270537
# 67   1.378647  1.258452  1.377451  1.258343  1.258136  1.257725  1.257308
# 117  1.524956  1.428004  1.523609  1.427889  1.427436  1.427210  1.427226
# 47   1.454723  1.353886  1.452482  1.353804  1.353888  1.353531  1.353050
# 172  1.355493  1.248350  1.353979  1.247937  1.247684  1.247314  1.246818
#
# [130 rows x 300 columns]

# %%
# calling the Linear Regression model
lr_model =  LinearRegression()
sfs = sfs(lr_model, k_features=80, forward=False, verbose=2, scoring='neg_root_mean_squared_error', n_jobs=-1)

# %%
# %%time

sfs = sfs.fit(x_train_selected, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done 292 out of 300 | elapsed:    7.5s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 300 out of 300 | elapsed:    7.5s finished
#
# [2022-07-14 22:59:00] Features: 299/80 -- score: -3509628.81994543[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 290 out of 299 | elapsed:    1.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 299 out of 299 | elapsed:    1.3s finished
#
# [2022-07-14 22:59:02] Features: 298/80 -- score: -2486034.5419186438[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 289 out of 298 | elapsed:    1.7s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 298 out of 298 | elapsed:    1.7s finished
#
# [2022-07-14 22:59:03] Features: 297/80 -- score: -3518262.5289049298[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 287 out of 297 | elapsed:    1.9s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 297 out of 297 | elapsed:    1.9s finished
#
# [2022-07-14 22:59:05] Features: 296/80 -- score: -3883637.047829633[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 286 out of 296 | elapsed:    2.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 296 out of 296 | elapsed:    2.1s finished
#
# [2022-07-14 22:59:07] Features: 295/80 -- score: -2274561.456853988[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 284 out of 295 | elapsed:    2.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 295 out of 295 | elapsed:    2.1s finished
#
# [2022-07-14 22:59:10] Features: 294/80 -- score: -3722165.3128846525[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 283 out of 294 | elapsed:    2.1s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 294 out of 294 | elapsed:    2.1s finished
#
# [2022-07-14 22:59:12] Features: 293/80 -- score: -2907944.3941384293[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 281 out of 293 | elapsed:    2.3s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 293 out of 293 | elapsed:    2.3s finished
#
# [2022-07-14 22:59:14] Features: 292/80 -- score: -3080495.4678825894[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 280 out of 292 | elapsed:    2.8s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 292 out of 292 | elapsed:    2.8s finished
#
# [2022-07-14 22:59:17] Features: 291/80 -- score: -3527716.5013596565[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 278 out of 291 | elapsed:    2.8s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 291 out of 291 | elapsed:    2.8s finished
#
# [2022-07-14 22:59:20] Features: 290/80 -- score: -1750869.0032118738[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 277 out of 290 | elapsed:    2.9s remaining:    0.1s
# [Parallel(n_jobs=-1)]: Done 290 out of 290 | elapsed:    2.9s finished
#
# [2022-07-14 22:59:23] Features: 289/80 -- score: -2013875.656738565[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 275 out of 289 | elapsed:    3.0s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 289 out of 289 | elapsed:    3.0s finished
#
# [2022-07-14 22:59:26] Features: 288/80 -- score: -3843716.2855239855[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 274 out of 288 | elapsed:    3.0s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 288 out of 288 | elapsed:    3.0s finished
#
# [2022-07-14 22:59:29] Features: 287/80 -- score: -3673043.311368338[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 272 out of 287 | elapsed:    3.5s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 287 out of 287 | elapsed:    3.5s finished
#
# [2022-07-14 22:59:32] Features: 286/80 -- score: -3446208.9813470244[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 271 out of 286 | elapsed:    3.4s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 286 out of 286 | elapsed:    3.4s finished
#
# [2022-07-14 22:59:36] Features: 285/80 -- score: -4424857.728305558[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 269 out of 285 | elapsed:    3.3s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 285 out of 285 | elapsed:    3.3s finished
#
# [2022-07-14 22:59:39] Features: 284/80 -- score: -2435911.4313047845[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 268 out of 284 | elapsed:    3.2s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 284 out of 284 | elapsed:    3.2s finished
#
# [2022-07-14 22:59:42] Features: 283/80 -- score: -3452120.756072141[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 266 out of 283 | elapsed:    3.5s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 283 out of 283 | elapsed:    3.5s finished
#
# [2022-07-14 22:59:46] Features: 282/80 -- score: -2799306.186394996[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 265 out of 282 | elapsed:    3.7s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 282 out of 282 | elapsed:    3.7s finished
#
# [2022-07-14 22:59:49] Features: 281/80 -- score: -3836054.7611433654[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 263 out of 281 | elapsed:    3.5s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 281 out of 281 | elapsed:    3.5s finished
#
# [2022-07-14 22:59:53] Features: 280/80 -- score: -3508373.9802816273[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 262 out of 280 | elapsed:    3.9s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 280 out of 280 | elapsed:    3.9s finished
#
# [2022-07-14 22:59:57] Features: 279/80 -- score: -3142482.517690839[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 260 out of 279 | elapsed:    4.1s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 279 out of 279 | elapsed:    4.1s finished
#
# [2022-07-14 23:00:01] Features: 278/80 -- score: -3114126.69106019[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 259 out of 278 | elapsed:    4.1s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 278 out of 278 | elapsed:    4.1s finished
#
# [2022-07-14 23:00:05] Features: 277/80 -- score: -3257619.772586497[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 257 out of 277 | elapsed:    4.0s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 277 out of 277 | elapsed:    4.0s finished
#
# [2022-07-14 23:00:09] Features: 276/80 -- score: -3165072.4057578114[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 256 out of 276 | elapsed:    4.3s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 276 out of 276 | elapsed:    4.3s finished
#
# [2022-07-14 23:00:13] Features: 275/80 -- score: -4007656.856451121[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 254 out of 275 | elapsed:    4.6s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 275 out of 275 | elapsed:    4.6s finished
#
# [2022-07-14 23:00:18] Features: 274/80 -- score: -2018685.2566797726[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 253 out of 274 | elapsed:    4.9s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 274 out of 274 | elapsed:    4.9s finished
#
# [2022-07-14 23:00:23] Features: 273/80 -- score: -2631736.60309861[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 251 out of 273 | elapsed:    4.9s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 273 out of 273 | elapsed:    4.9s finished
#
# [2022-07-14 23:00:28] Features: 272/80 -- score: -3102601.7901183413[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 250 out of 272 | elapsed:    4.4s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 272 out of 272 | elapsed:    4.8s finished
#
# [2022-07-14 23:00:33] Features: 271/80 -- score: -2600415.269445195[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 248 out of 271 | elapsed:    4.8s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 271 out of 271 | elapsed:    4.8s finished
#
# [2022-07-14 23:00:37] Features: 270/80 -- score: -3712860.9798268126[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 247 out of 270 | elapsed:    5.0s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 270 out of 270 | elapsed:    5.0s finished
#
# [2022-07-14 23:00:42] Features: 269/80 -- score: -2070469.932936461[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 245 out of 269 | elapsed:    4.8s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 269 out of 269 | elapsed:    4.8s finished
#
# [2022-07-14 23:00:47] Features: 268/80 -- score: -3929473.9056002693[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 244 out of 268 | elapsed:    5.0s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 268 out of 268 | elapsed:    5.0s finished
#
# [2022-07-14 23:00:52] Features: 267/80 -- score: -2676414.0556828086[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 242 out of 267 | elapsed:    5.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 267 out of 267 | elapsed:    5.2s finished
#
# [2022-07-14 23:00:57] Features: 266/80 -- score: -1184476.9827565644[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 241 out of 266 | elapsed:    5.0s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 266 out of 266 | elapsed:    5.1s finished
#
# [2022-07-14 23:01:03] Features: 265/80 -- score: -3458395.1580962157[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 239 out of 265 | elapsed:    5.0s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 265 out of 265 | elapsed:    5.4s finished
#
# [2022-07-14 23:01:08] Features: 264/80 -- score: -2736643.8108409317[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 238 out of 264 | elapsed:    5.2s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 264 out of 264 | elapsed:    5.6s finished
#
# [2022-07-14 23:01:14] Features: 263/80 -- score: -2872073.2279177755[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 236 out of 263 | elapsed:    5.7s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 263 out of 263 | elapsed:    5.7s finished
#
# [2022-07-14 23:01:19] Features: 262/80 -- score: -3045665.3715004823[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 235 out of 262 | elapsed:    5.5s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 262 out of 262 | elapsed:    5.5s finished
#
# [2022-07-14 23:01:25] Features: 261/80 -- score: -3474339.788985134[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 233 out of 261 | elapsed:    5.5s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 261 out of 261 | elapsed:    5.9s finished
#
# [2022-07-14 23:01:31] Features: 260/80 -- score: -2696490.0505565912[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 232 out of 260 | elapsed:    5.2s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 260 out of 260 | elapsed:    5.8s finished
#
# [2022-07-14 23:01:37] Features: 259/80 -- score: -3428340.2879729094[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 230 out of 259 | elapsed:    5.7s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 259 out of 259 | elapsed:    5.7s finished
#
# [2022-07-14 23:01:42] Features: 258/80 -- score: -2455430.932627577[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 229 out of 258 | elapsed:    5.9s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 258 out of 258 | elapsed:    6.0s finished
#
# [2022-07-14 23:01:48] Features: 257/80 -- score: -3898997.447273647[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 227 out of 257 | elapsed:    5.4s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 257 out of 257 | elapsed:    6.1s finished
#
# [2022-07-14 23:01:54] Features: 256/80 -- score: -3054002.2149887015[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 226 out of 256 | elapsed:    5.5s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 256 out of 256 | elapsed:    6.2s finished
#
# [2022-07-14 23:02:01] Features: 255/80 -- score: -2717084.567048662[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 224 out of 255 | elapsed:    5.5s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 255 out of 255 | elapsed:    6.2s finished
#
# [2022-07-14 23:02:07] Features: 254/80 -- score: -1857174.475062263[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 223 out of 254 | elapsed:    5.7s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 254 out of 254 | elapsed:    6.4s finished
#
# [2022-07-14 23:02:13] Features: 253/80 -- score: -2455966.643309978[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 221 out of 253 | elapsed:    5.8s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 253 out of 253 | elapsed:    6.5s finished
#
# [2022-07-14 23:02:20] Features: 252/80 -- score: -3561511.832684937[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 220 out of 252 | elapsed:    5.4s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 252 out of 252 | elapsed:    6.2s finished
#
# [2022-07-14 23:02:26] Features: 251/80 -- score: -3431889.1262508584[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 218 out of 251 | elapsed:    5.6s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 251 out of 251 | elapsed:    6.4s finished
#
# [2022-07-14 23:02:32] Features: 250/80 -- score: -1562721.974580702[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 217 out of 250 | elapsed:    5.7s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:    6.3s finished
#
# [2022-07-14 23:02:39] Features: 249/80 -- score: -2799982.6642354527[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 215 out of 249 | elapsed:    5.6s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 249 out of 249 | elapsed:    6.4s finished
#
# [2022-07-14 23:02:45] Features: 248/80 -- score: -3289155.654703751[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 214 out of 248 | elapsed:    6.0s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 248 out of 248 | elapsed:    6.7s finished
#
# [2022-07-14 23:02:52] Features: 247/80 -- score: -2462810.618951713[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 212 out of 247 | elapsed:    6.1s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 247 out of 247 | elapsed:    6.7s finished
#
# [2022-07-14 23:02:59] Features: 246/80 -- score: -2011283.4301332235[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 211 out of 246 | elapsed:    5.9s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 246 out of 246 | elapsed:    6.7s finished
#
# [2022-07-14 23:03:05] Features: 245/80 -- score: -2149107.1618530396[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 209 out of 245 | elapsed:    5.9s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 245 out of 245 | elapsed:    6.5s finished
#
# [2022-07-14 23:03:12] Features: 244/80 -- score: -2373449.293174043[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 208 out of 244 | elapsed:    6.2s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 244 out of 244 | elapsed:    6.8s finished
#
# [2022-07-14 23:03:19] Features: 243/80 -- score: -3094418.033899747[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 206 out of 243 | elapsed:    5.7s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 243 out of 243 | elapsed:    6.6s finished
#
# [2022-07-14 23:03:25] Features: 242/80 -- score: -2384732.9856489776[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 205 out of 242 | elapsed:    6.0s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 242 out of 242 | elapsed:    6.9s finished
#
# [2022-07-14 23:03:32] Features: 241/80 -- score: -2215705.144414509[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 203 out of 241 | elapsed:    6.0s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 241 out of 241 | elapsed:    7.0s finished
#
# [2022-07-14 23:03:39] Features: 240/80 -- score: -3716334.7719596564[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 202 out of 240 | elapsed:    5.9s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 240 out of 240 | elapsed:    7.0s finished
#
# [2022-07-14 23:03:46] Features: 239/80 -- score: -2145486.754535[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 200 out of 239 | elapsed:    5.9s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done 239 out of 239 | elapsed:    7.0s finished
#
# [2022-07-14 23:03:53] Features: 238/80 -- score: -2793063.1024079705[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 199 out of 238 | elapsed:    6.0s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 238 out of 238 | elapsed:    7.2s finished
#
# [2022-07-14 23:04:01] Features: 237/80 -- score: -3959239.7742422163[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 197 out of 237 | elapsed:    5.7s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 237 out of 237 | elapsed:    6.9s finished
#
# [2022-07-14 23:04:08] Features: 236/80 -- score: -3513365.2839348107[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 196 out of 236 | elapsed:    5.8s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 236 out of 236 | elapsed:    7.0s finished
#
# [2022-07-14 23:04:14] Features: 235/80 -- score: -2588634.8393068635[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 194 out of 235 | elapsed:    5.8s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 235 out of 235 | elapsed:    7.0s finished
#
# [2022-07-14 23:04:22] Features: 234/80 -- score: -2911103.627215082[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 193 out of 234 | elapsed:    5.8s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done 234 out of 234 | elapsed:    7.1s finished
#
# [2022-07-14 23:04:29] Features: 233/80 -- score: -2741420.126587528[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 191 out of 233 | elapsed:    5.9s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 233 out of 233 | elapsed:    7.1s finished
#
# [2022-07-14 23:04:36] Features: 232/80 -- score: -1770755.2683938518[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 190 out of 232 | elapsed:    6.3s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done 232 out of 232 | elapsed:    7.7s finished
#
# [2022-07-14 23:04:43] Features: 231/80 -- score: -3784699.460892177[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 188 out of 231 | elapsed:    6.3s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done 231 out of 231 | elapsed:    7.6s finished
#
# [2022-07-14 23:04:51] Features: 230/80 -- score: -3617052.6501814066[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 187 out of 230 | elapsed:    5.9s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done 230 out of 230 | elapsed:    7.2s finished
#
# [2022-07-14 23:04:58] Features: 229/80 -- score: -2111819.640061946[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 185 out of 229 | elapsed:    6.0s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done 229 out of 229 | elapsed:    7.6s finished
#
# [2022-07-14 23:05:06] Features: 228/80 -- score: -4246353.978739442[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 184 out of 228 | elapsed:    6.0s remaining:    1.4s
# [Parallel(n_jobs=-1)]: Done 228 out of 228 | elapsed:    7.3s finished
#
# [2022-07-14 23:05:13] Features: 227/80 -- score: -1307159.5213252602[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 182 out of 227 | elapsed:    5.9s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 227 out of 227 | elapsed:    7.4s finished
#
# [2022-07-14 23:05:21] Features: 226/80 -- score: -2578175.0714045363[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 181 out of 226 | elapsed:    6.0s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done 226 out of 226 | elapsed:    7.5s finished
#
# [2022-07-14 23:05:28] Features: 225/80 -- score: -1834890.8613076352[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 179 out of 225 | elapsed:    6.1s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 225 out of 225 | elapsed:    7.7s finished
#
# [2022-07-14 23:05:36] Features: 224/80 -- score: -3306830.9196190834[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 178 out of 224 | elapsed:    6.3s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 224 out of 224 | elapsed:    7.9s finished
#
# [2022-07-14 23:05:44] Features: 223/80 -- score: -3159588.2074587857[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 176 out of 223 | elapsed:    6.1s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done 223 out of 223 | elapsed:    7.6s finished
#
# [2022-07-14 23:05:51] Features: 222/80 -- score: -2516164.5829580636[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 175 out of 222 | elapsed:    6.5s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 222 out of 222 | elapsed:    8.2s finished
#
# [2022-07-14 23:06:00] Features: 221/80 -- score: -3801173.0205821553[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 173 out of 221 | elapsed:    6.7s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 221 out of 221 | elapsed:    8.4s finished
#
# [2022-07-14 23:06:08] Features: 220/80 -- score: -2944057.654834083[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 172 out of 220 | elapsed:    6.3s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 220 out of 220 | elapsed:    7.9s finished
#
# [2022-07-14 23:06:16] Features: 219/80 -- score: -4225741.289949248[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 170 out of 219 | elapsed:    6.5s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 219 out of 219 | elapsed:    8.3s finished
#
# [2022-07-14 23:06:24] Features: 218/80 -- score: -3644070.097460903[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 169 out of 218 | elapsed:    6.6s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 218 out of 218 | elapsed:    8.4s finished
#
# [2022-07-14 23:06:33] Features: 217/80 -- score: -3163288.308801892[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 167 out of 217 | elapsed:    6.4s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 217 out of 217 | elapsed:    8.4s finished
#
# [2022-07-14 23:06:41] Features: 216/80 -- score: -3665999.306487914[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 166 out of 216 | elapsed:    6.0s remaining:    1.8s
# [Parallel(n_jobs=-1)]: Done 216 out of 216 | elapsed:    7.8s finished
#
# [2022-07-14 23:06:49] Features: 215/80 -- score: -3059427.3130812785[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 164 out of 215 | elapsed:    6.3s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 215 out of 215 | elapsed:    8.1s finished
#
# [2022-07-14 23:06:57] Features: 214/80 -- score: -3933343.521266263[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 163 out of 214 | elapsed:    6.0s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done 214 out of 214 | elapsed:    7.9s finished
#
# [2022-07-14 23:07:05] Features: 213/80 -- score: -2529679.86059573[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 161 out of 213 | elapsed:    6.3s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 213 out of 213 | elapsed:    8.2s finished
#
# [2022-07-14 23:07:13] Features: 212/80 -- score: -2223782.000506657[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 160 out of 212 | elapsed:    6.0s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 212 out of 212 | elapsed:    7.9s finished
#
# [2022-07-14 23:07:21] Features: 211/80 -- score: -3085392.625269088[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 158 out of 211 | elapsed:    6.0s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 211 out of 211 | elapsed:    8.0s finished
#
# [2022-07-14 23:07:29] Features: 210/80 -- score: -2609878.895106247[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 157 out of 210 | elapsed:    6.0s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done 210 out of 210 | elapsed:    8.0s finished
#
# [2022-07-14 23:07:37] Features: 209/80 -- score: -2316909.549837013[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  18 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 155 out of 209 | elapsed:    6.4s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 209 out of 209 | elapsed:    8.4s finished
#
# [2022-07-14 23:07:46] Features: 208/80 -- score: -5985813.3908796515[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 154 out of 208 | elapsed:    6.3s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 208 out of 208 | elapsed:    8.4s finished
#
# [2022-07-14 23:07:54] Features: 207/80 -- score: -2850397.8842618493[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 152 out of 207 | elapsed:    6.4s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 207 out of 207 | elapsed:    8.6s finished
#
# [2022-07-14 23:08:03] Features: 206/80 -- score: -4320770.116246821[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 151 out of 206 | elapsed:    6.0s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 206 out of 206 | elapsed:    8.1s finished
#
# [2022-07-14 23:08:11] Features: 205/80 -- score: -6006688.473822598[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 149 out of 205 | elapsed:    5.8s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 205 out of 205 | elapsed:    8.2s finished
#
# [2022-07-14 23:08:19] Features: 204/80 -- score: -6981977.874188928[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 148 out of 204 | elapsed:    6.4s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 204 out of 204 | elapsed:    8.6s finished
#
# [2022-07-14 23:08:27] Features: 203/80 -- score: -3946461.5591105083[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 146 out of 203 | elapsed:    6.0s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 203 out of 203 | elapsed:    8.2s finished
#
# [2022-07-14 23:08:36] Features: 202/80 -- score: -4560658.560708205[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 145 out of 202 | elapsed:    6.0s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 202 out of 202 | elapsed:    8.2s finished
#
# [2022-07-14 23:08:44] Features: 201/80 -- score: -4422019.99168815[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 143 out of 201 | elapsed:    5.9s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 201 out of 201 | elapsed:    8.1s finished
#
# [2022-07-14 23:08:52] Features: 200/80 -- score: -17193085.725683987[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 142 out of 200 | elapsed:    5.8s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 200 out of 200 | elapsed:    8.2s finished
#
# [2022-07-14 23:09:00] Features: 199/80 -- score: -12510370.100589393[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 140 out of 199 | elapsed:    5.7s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 199 out of 199 | elapsed:    8.0s finished
#
# [2022-07-14 23:09:08] Features: 198/80 -- score: -13468988.16938417[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 139 out of 198 | elapsed:    5.5s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 198 out of 198 | elapsed:    7.8s finished
#
# [2022-07-14 23:09:16] Features: 197/80 -- score: -20591008.57604313[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 137 out of 197 | elapsed:    5.5s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 197 out of 197 | elapsed:    7.9s finished
#
# [2022-07-14 23:09:24] Features: 196/80 -- score: -19691163.368691675[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 136 out of 196 | elapsed:    5.5s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 196 out of 196 | elapsed:    7.9s finished
#
# [2022-07-14 23:09:32] Features: 195/80 -- score: -20619051.404394068[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 134 out of 195 | elapsed:    5.5s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done 195 out of 195 | elapsed:    7.9s finished
#
# [2022-07-14 23:09:40] Features: 194/80 -- score: -23361456.461452056[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 133 out of 194 | elapsed:    5.6s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 194 out of 194 | elapsed:    8.2s finished
#
# [2022-07-14 23:09:48] Features: 193/80 -- score: -16148950.4964466[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 131 out of 193 | elapsed:    6.4s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 193 out of 193 | elapsed:    9.4s finished
#
# [2022-07-14 23:09:57] Features: 192/80 -- score: -22224181.65178422[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 130 out of 192 | elapsed:    5.5s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 192 out of 192 | elapsed:    8.0s finished
#
# [2022-07-14 23:10:06] Features: 191/80 -- score: -15719374.346351018[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 128 out of 191 | elapsed:    5.5s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done 191 out of 191 | elapsed:    8.4s finished
#
# [2022-07-14 23:10:14] Features: 190/80 -- score: -17008862.940664303[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 127 out of 190 | elapsed:    5.6s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 190 out of 190 | elapsed:    8.2s finished
#
# [2022-07-14 23:10:22] Features: 189/80 -- score: -17648314.632818427[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 125 out of 189 | elapsed:    5.4s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 189 out of 189 | elapsed:    8.1s finished
#
# [2022-07-14 23:10:30] Features: 188/80 -- score: -17709209.66328939[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 124 out of 188 | elapsed:    6.0s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done 188 out of 188 | elapsed:    9.2s finished
#
# [2022-07-14 23:10:40] Features: 187/80 -- score: -28146124.110140096[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 122 out of 187 | elapsed:    5.7s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done 187 out of 187 | elapsed:    8.7s finished
#
# [2022-07-14 23:10:48] Features: 186/80 -- score: -22183052.961107932[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 121 out of 186 | elapsed:    5.3s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 186 out of 186 | elapsed:    8.0s finished
#
# [2022-07-14 23:10:56] Features: 185/80 -- score: -16807798.165765576[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 119 out of 185 | elapsed:    5.3s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 185 out of 185 | elapsed:    8.1s finished
#
# [2022-07-14 23:11:04] Features: 184/80 -- score: -14978998.973165762[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 118 out of 184 | elapsed:    5.3s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 184 out of 184 | elapsed:    8.1s finished
#
# [2022-07-14 23:11:12] Features: 183/80 -- score: -24663648.895528346[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 116 out of 183 | elapsed:    5.2s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 183 out of 183 | elapsed:    8.1s finished
#
# [2022-07-14 23:11:21] Features: 182/80 -- score: -23155005.285308413[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 115 out of 182 | elapsed:    5.1s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 182 out of 182 | elapsed:    8.0s finished
#
# [2022-07-14 23:11:29] Features: 181/80 -- score: -20335868.022345223[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 113 out of 181 | elapsed:    5.0s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 181 out of 181 | elapsed:    8.1s finished
#
# [2022-07-14 23:11:37] Features: 180/80 -- score: -12833226.370250273[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 112 out of 180 | elapsed:    5.2s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done 180 out of 180 | elapsed:    8.1s finished
#
# [2022-07-14 23:11:45] Features: 179/80 -- score: -23046672.33562277[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 110 out of 179 | elapsed:    5.4s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done 179 out of 179 | elapsed:    8.7s finished
#
# [2022-07-14 23:11:54] Features: 178/80 -- score: -19631529.1777594[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 109 out of 178 | elapsed:    5.1s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 178 out of 178 | elapsed:    8.3s finished
#
# [2022-07-14 23:12:02] Features: 177/80 -- score: -9089781.37754831[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 107 out of 177 | elapsed:    5.6s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done 177 out of 177 | elapsed:    9.0s finished
#
# [2022-07-14 23:12:11] Features: 176/80 -- score: -14518617.876020342[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 106 out of 176 | elapsed:    4.9s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 176 out of 176 | elapsed:    8.0s finished
#
# [2022-07-14 23:12:19] Features: 175/80 -- score: -25343343.166089036[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 104 out of 175 | elapsed:    5.5s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 175 out of 175 | elapsed:    9.6s finished
#
# [2022-07-14 23:12:29] Features: 174/80 -- score: -15935467.756009523[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 103 out of 174 | elapsed:    5.1s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done 174 out of 174 | elapsed:    8.3s finished
#
# [2022-07-14 23:12:37] Features: 173/80 -- score: -21363445.02563889[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 101 out of 173 | elapsed:    4.8s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done 173 out of 173 | elapsed:    8.1s finished
#
# [2022-07-14 23:12:45] Features: 172/80 -- score: -12676473.634070527[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 100 out of 172 | elapsed:    4.9s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done 172 out of 172 | elapsed:    8.3s finished
#
# [2022-07-14 23:12:53] Features: 171/80 -- score: -20177494.051285423[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done  98 out of 171 | elapsed:    4.8s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done 171 out of 171 | elapsed:    8.3s finished
#
# [2022-07-14 23:13:02] Features: 170/80 -- score: -14835027.645490697[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   6 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  97 out of 170 | elapsed:    4.7s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done 170 out of 170 | elapsed:    8.1s finished
#
# [2022-07-14 23:13:10] Features: 169/80 -- score: -27033107.15840293[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  95 out of 169 | elapsed:    4.8s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 169 out of 169 | elapsed:    8.4s finished
#
# [2022-07-14 23:13:18] Features: 168/80 -- score: -21107194.791475095[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done  94 out of 168 | elapsed:    4.7s remaining:    3.7s
# [Parallel(n_jobs=-1)]: Done 168 out of 168 | elapsed:    8.4s finished
#
# [2022-07-14 23:13:27] Features: 167/80 -- score: -30038262.670684446[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# ...
#
# [2022-07-14 23:19:19] Features: 122/80 -- score: -45656098.214108504[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  25 out of 122 | elapsed:    1.6s remaining:    6.1s
# [Parallel(n_jobs=-1)]: Done  87 out of 122 | elapsed:    5.7s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 122 out of 122 | elapsed:    7.7s finished
#
# [2022-07-14 23:19:27] Features: 121/80 -- score: -67773203.57624942[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of 121 | elapsed:    1.5s remaining:    6.3s
# [Parallel(n_jobs=-1)]: Done  84 out of 121 | elapsed:    4.9s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 121 out of 121 | elapsed:    7.0s finished
#
# [2022-07-14 23:19:34] Features: 120/80 -- score: -65410789.97209825[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  22 out of 120 | elapsed:    1.3s remaining:    6.0s
# [Parallel(n_jobs=-1)]: Done  83 out of 120 | elapsed:    5.0s remaining:    2.2s
# [Parallel(n_jobs=-1)]: Done 120 out of 120 | elapsed:    7.4s finished
#
# [2022-07-14 23:19:42] Features: 119/80 -- score: -24871578.289094165[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of 119 | elapsed:    1.2s remaining:    6.1s
# [Parallel(n_jobs=-1)]: Done  80 out of 119 | elapsed:    4.7s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 119 out of 119 | elapsed:    7.0s finished
#
# [2022-07-14 23:19:48] Features: 118/80 -- score: -48808467.50169303[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of 118 | elapsed:    1.2s remaining:    6.1s
# [Parallel(n_jobs=-1)]: Done  79 out of 118 | elapsed:    4.6s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done 118 out of 118 | elapsed:    6.9s finished
#
# [2022-07-14 23:19:55] Features: 117/80 -- score: -37495317.40065282[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  17 out of 117 | elapsed:    1.1s remaining:    6.2s
# [Parallel(n_jobs=-1)]: Done  76 out of 117 | elapsed:    4.5s remaining:    2.4s
# [Parallel(n_jobs=-1)]: Done 117 out of 117 | elapsed:    6.9s finished
#
# [2022-07-14 23:20:02] Features: 116/80 -- score: -47884710.18390838[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of 116 | elapsed:    1.0s remaining:    6.3s
# [Parallel(n_jobs=-1)]: Done  75 out of 116 | elapsed:    4.6s remaining:    2.5s
# [Parallel(n_jobs=-1)]: Done 116 out of 116 | elapsed:    7.0s finished
#
# [2022-07-14 23:20:09] Features: 115/80 -- score: -59505296.885873064[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  14 out of 115 | elapsed:    0.9s remaining:    6.8s
# [Parallel(n_jobs=-1)]: Done  72 out of 115 | elapsed:    4.5s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done 115 out of 115 | elapsed:    7.0s finished
#
# [2022-07-14 23:20:16] Features: 114/80 -- score: -85788288.9963264[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  13 out of 114 | elapsed:    0.9s remaining:    6.8s
# [Parallel(n_jobs=-1)]: Done  71 out of 114 | elapsed:    4.4s remaining:    2.6s
# [Parallel(n_jobs=-1)]: Done 114 out of 114 | elapsed:    6.8s finished
#
# [2022-07-14 23:20:23] Features: 113/80 -- score: -37352049.340704665[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of 113 | elapsed:    0.7s remaining:    6.6s
# [Parallel(n_jobs=-1)]: Done  68 out of 113 | elapsed:    4.0s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done 113 out of 113 | elapsed:    6.6s finished
#
# [2022-07-14 23:20:30] Features: 112/80 -- score: -72349254.09125534[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 out of 112 | elapsed:    0.7s remaining:    6.7s
# [Parallel(n_jobs=-1)]: Done  67 out of 112 | elapsed:    4.0s remaining:    2.7s
# [Parallel(n_jobs=-1)]: Done 112 out of 112 | elapsed:    6.7s finished
#
# [2022-07-14 23:20:36] Features: 111/80 -- score: -59680371.780321345[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of 111 | elapsed:    0.5s remaining:    6.9s
# [Parallel(n_jobs=-1)]: Done  64 out of 111 | elapsed:    3.8s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 111 out of 111 | elapsed:    6.6s finished
#
# [2022-07-14 23:20:43] Features: 110/80 -- score: -50839693.03827782[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of 110 | elapsed:    0.5s remaining:    7.1s
# [Parallel(n_jobs=-1)]: Done  63 out of 110 | elapsed:    3.8s remaining:    2.8s
# [Parallel(n_jobs=-1)]: Done 110 out of 110 | elapsed:    6.5s finished
#
# [2022-07-14 23:20:50] Features: 109/80 -- score: -113386776.73110695[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 out of 109 | elapsed:    0.4s remaining:    7.8s
# [Parallel(n_jobs=-1)]: Done  60 out of 109 | elapsed:    3.6s remaining:    2.9s
# [Parallel(n_jobs=-1)]: Done 109 out of 109 | elapsed:    6.5s finished
#
# [2022-07-14 23:20:56] Features: 108/80 -- score: -83136528.91517788[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of 108 | elapsed:    0.3s remaining:    8.1s
# [Parallel(n_jobs=-1)]: Done  59 out of 108 | elapsed:    3.6s remaining:    3.0s
# [Parallel(n_jobs=-1)]: Done 108 out of 108 | elapsed:    6.4s finished
#
# [2022-07-14 23:21:03] Features: 107/80 -- score: -88456274.7958762[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 out of 107 | elapsed:    0.2s remaining:    9.8s
# [Parallel(n_jobs=-1)]: Done  56 out of 107 | elapsed:    3.4s remaining:    3.1s
# [Parallel(n_jobs=-1)]: Done 107 out of 107 | elapsed:    6.5s finished
#
# [2022-07-14 23:21:09] Features: 106/80 -- score: -79491235.9908351[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  55 out of 106 | elapsed:    3.4s remaining:    3.2s
# [Parallel(n_jobs=-1)]: Done 106 out of 106 | elapsed:    6.5s finished
#
# [2022-07-14 23:21:16] Features: 105/80 -- score: -80562502.67706431[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  52 out of 105 | elapsed:    3.2s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    6.4s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 105 out of 105 | elapsed:    6.4s finished
#
# [2022-07-14 23:21:22] Features: 104/80 -- score: -18571817599.733967[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  51 out of 104 | elapsed:    3.2s remaining:    3.3s
# [Parallel(n_jobs=-1)]: Done 104 out of 104 | elapsed:    6.3s remaining:    0.0s
# [Parallel(n_jobs=-1)]: Done 104 out of 104 | elapsed:    6.3s finished
#
# [2022-07-14 23:21:28] Features: 103/80 -- score: -8878782824.794798[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  48 out of 103 | elapsed:    3.0s remaining:    3.4s
# [Parallel(n_jobs=-1)]: Done 100 out of 103 | elapsed:    6.2s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 103 out of 103 | elapsed:    6.4s finished
#
# [2022-07-14 23:21:35] Features: 102/80 -- score: -16635787064.477854[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  47 out of 102 | elapsed:    3.0s remaining:    3.5s
# [Parallel(n_jobs=-1)]: Done  99 out of 102 | elapsed:    6.2s remaining:    0.2s
# [Parallel(n_jobs=-1)]: Done 102 out of 102 | elapsed:    6.3s finished
#
# [2022-07-14 23:21:41] Features: 101/80 -- score: -28882277338.967064[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  44 out of 101 | elapsed:    2.8s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done  95 out of 101 | elapsed:    5.9s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 101 out of 101 | elapsed:    6.3s finished
#
# [2022-07-14 23:21:47] Features: 100/80 -- score: -16354850935.989359[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  43 out of 100 | elapsed:    2.7s remaining:    3.6s
# [Parallel(n_jobs=-1)]: Done  94 out of 100 | elapsed:    5.9s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:    6.3s finished
#
# [2022-07-14 23:21:54] Features: 99/80 -- score: -14910048931.521265[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  40 out of  99 | elapsed:    2.9s remaining:    4.3s
# [Parallel(n_jobs=-1)]: Done  90 out of  99 | elapsed:    6.2s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  99 out of  99 | elapsed:    6.7s finished
#
# [2022-07-14 23:22:00] Features: 98/80 -- score: -19122465575.205933[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  39 out of  98 | elapsed:    2.6s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done  89 out of  98 | elapsed:    5.9s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done  98 out of  98 | elapsed:    6.5s finished
#
# [2022-07-14 23:22:07] Features: 97/80 -- score: -14232175764.278072[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  36 out of  97 | elapsed:    2.4s remaining:    4.1s
# [Parallel(n_jobs=-1)]: Done  85 out of  97 | elapsed:    5.7s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  97 out of  97 | elapsed:    6.5s finished
#
# [2022-07-14 23:22:13] Features: 96/80 -- score: -10170891087.62357[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  96 | elapsed:    2.3s remaining:    4.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  96 | elapsed:    5.4s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done  96 out of  96 | elapsed:    6.2s finished
#
# [2022-07-14 23:22:20] Features: 95/80 -- score: -10471900614.223814[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  32 out of  95 | elapsed:    2.1s remaining:    4.2s
# [Parallel(n_jobs=-1)]: Done  80 out of  95 | elapsed:    5.1s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done  95 out of  95 | elapsed:    6.1s finished
#
# [2022-07-14 23:22:26] Features: 94/80 -- score: -6731383791.20137[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  31 out of  94 | elapsed:    2.3s remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done  79 out of  94 | elapsed:    5.6s remaining:    1.1s
# [Parallel(n_jobs=-1)]: Done  94 out of  94 | elapsed:    6.6s finished
#
# [2022-07-14 23:22:32] Features: 93/80 -- score: -10995168664.379333[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  28 out of  93 | elapsed:    2.1s remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done  75 out of  93 | elapsed:    5.3s remaining:    1.3s
# [Parallel(n_jobs=-1)]: Done  93 out of  93 | elapsed:    6.5s finished
#
# [2022-07-14 23:22:39] Features: 92/80 -- score: -8149532126.278006[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  27 out of  92 | elapsed:    1.9s remaining:    4.6s
# [Parallel(n_jobs=-1)]: Done  74 out of  92 | elapsed:    5.1s remaining:    1.2s
# [Parallel(n_jobs=-1)]: Done  92 out of  92 | elapsed:    6.3s finished
#
# [2022-07-14 23:22:45] Features: 91/80 -- score: -11799856658.938946[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  24 out of  91 | elapsed:    1.7s remaining:    4.8s
# [Parallel(n_jobs=-1)]: Done  70 out of  91 | elapsed:    4.9s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done  91 out of  91 | elapsed:    6.3s finished
#
# [2022-07-14 23:22:51] Features: 90/80 -- score: -10850679874.844107[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  23 out of  90 | elapsed:    1.7s remaining:    5.0s
# [Parallel(n_jobs=-1)]: Done  69 out of  90 | elapsed:    4.8s remaining:    1.5s
# [Parallel(n_jobs=-1)]: Done  90 out of  90 | elapsed:    6.2s finished
#
# [2022-07-14 23:22:58] Features: 89/80 -- score: -8261325351.686511[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  20 out of  89 | elapsed:    1.4s remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done  65 out of  89 | elapsed:    4.4s remaining:    1.6s
# [Parallel(n_jobs=-1)]: Done  89 out of  89 | elapsed:    6.1s finished
#
# [2022-07-14 23:23:04] Features: 88/80 -- score: -3472257383.583314[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  19 out of  88 | elapsed:    1.3s remaining:    4.9s
# [Parallel(n_jobs=-1)]: Done  64 out of  88 | elapsed:    4.5s remaining:    1.7s
# [Parallel(n_jobs=-1)]: Done  88 out of  88 | elapsed:    6.1s finished
#
# [2022-07-14 23:23:10] Features: 87/80 -- score: -2277383617.247583[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  16 out of  87 | elapsed:    1.2s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  60 out of  87 | elapsed:    4.2s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done  87 out of  87 | elapsed:    6.1s finished
#
# [2022-07-14 23:23:16] Features: 86/80 -- score: -2179748365.204032[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  15 out of  86 | elapsed:    1.1s remaining:    5.3s
# [Parallel(n_jobs=-1)]: Done  59 out of  86 | elapsed:    4.2s remaining:    1.9s
# [Parallel(n_jobs=-1)]: Done  86 out of  86 | elapsed:    6.0s finished
#
# [2022-07-14 23:23:22] Features: 85/80 -- score: -602828297.0727426[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  12 out of  85 | elapsed:    0.9s remaining:    5.3s
# [Parallel(n_jobs=-1)]: Done  55 out of  85 | elapsed:    3.7s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  85 out of  85 | elapsed:    5.7s finished
#
# [2022-07-14 23:23:27] Features: 84/80 -- score: -118152087.43300605[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  11 out of  84 | elapsed:    0.8s remaining:    5.2s
# [Parallel(n_jobs=-1)]: Done  54 out of  84 | elapsed:    3.6s remaining:    2.0s
# [Parallel(n_jobs=-1)]: Done  84 out of  84 | elapsed:    5.6s finished
#
# [2022-07-14 23:23:33] Features: 83/80 -- score: -34322499.325130746[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 out of  83 | elapsed:    0.6s remaining:    5.6s
# [Parallel(n_jobs=-1)]: Done  50 out of  83 | elapsed:    3.5s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done  83 out of  83 | elapsed:    5.7s finished
#
# [2022-07-14 23:23:39] Features: 82/80 -- score: -96.00340331170523[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 out of  82 | elapsed:    0.5s remaining:    5.8s
# [Parallel(n_jobs=-1)]: Done  49 out of  82 | elapsed:    3.4s remaining:    2.3s
# [Parallel(n_jobs=-1)]: Done  82 out of  82 | elapsed:    5.6s finished
#
# [2022-07-14 23:23:44] Features: 81/80 -- score: -46.175279805962376[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 out of  81 | elapsed:    0.3s remaining:    6.4s
# [Parallel(n_jobs=-1)]: Done  45 out of  81 | elapsed:    3.1s remaining:    2.5s
# CPU times: user 24min 47s, sys: 25.7 s, total: 25min 13s
# Wall time: 24min 57s
# [Parallel(n_jobs=-1)]: Done  81 out of  81 | elapsed:    5.5s finished
#
# [2022-07-14 23:23:50] Features: 80/80 -- score: -39.94944774750422

# %%
feat_names = list(sfs.k_feature_names_)
print("Fitur yang diambil adalah: ")
print(feat_names)
len(feat_names)
# Out:
# Fitur yang diambil adalah:
# ['2500.2', '1845.4', '1857.3', '1838.8', '1837.5', '1905', '1896.7', '1913.5', '1885.6', '1723.9', '1726.2', '1732', '1789.3', '1798', '1805.5', '1768.6', '1785.6', '1923.4', '2102.8', '2109.6', '2067.6', '2000.6', '1496.1', '1478.2', '1538.7', '1425.4', '1455.8', '1442', '1669.5', '1671.7', '1706.9', '1711.4', '1612.4', '1623.5', '1493.5', '1600.5', '2350.6', '1595.5', '1592.6', '1591.6', '2418.6', '1586.7', '1621.5', '1620.5', '2414.1', '1615.4', '2411.8', '1611.4', '1584.8', '1561.9', '1559.1', '1557.2', '1551.6', '1563.8', '1566.6', '1580.9', '1578', '1574.2', '1567.6', '1625.5', '1679.2', '1678.1', '1674.9', '1709.1', '1672.7', '2385.2', '1645.1', '1643.1', '1637.9', '1632.7', '1648.3', '1668.4', '1666.3', '1665.2', '1664.1', '2376.5', '1652.5', '2365.6', '1585.8', '1446.8']
# 80

# %% [markdown]
# # Prediksi Linear Regression

# %%
#cross validation 10-fold
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [80]

for nfeat in n_feat:
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur Fisher Score
        x_train_selected = x_train[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]
        x_test_selected = x_test[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]

        #Create a Linear Regression
        lr_model = LinearRegression()
        
        #Train the model using the training sets
        lr_model.fit(x_train_selected, y_train)
        y_pred_lr = lr_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(lr_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Linear Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Linear data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_lr), 2))))
        print("RMSE model Linear data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_lr, squared = False), 2))))
        print("MAE model Linear data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_lr), 2))))
        print("R2 model Linear data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_lr), 2))))
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 80 fitur: 41.11
# RMSE model Linear Regression data Train dengan 80 fitur:6.4
# MAE model Linear Regression data Train dengan 80 fitur:4.74
# R2 model Linear Regression data Train dengan 80 fitur:0.79
# ----------------------------
# MSE model Linear data Test dengan 80 fitur:1316.32
# RMSE model Linear data Test dengan 80 fitur:36.28
# MAE model Linear data Test dengan 80 fitur:20.99
# R2 model Linear data Test dengan 80 fitur:6.63
# ==================================================
# CPU times: user 11.9 s, sys: 328 ms, total: 12.2 s
# Wall time: 483 ms

# %% [markdown]
# # Prediksi Random Forest Regressor

# %% [markdown]
# ## 100 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [80]
n_trees = [100]

for nfeat in n_feat:
    for ntrees in n_trees:
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur Fisher Score
        x_train_selected = x_train[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]
        x_test_selected = x_test[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 80 fitur: 38.75
# RMSE model Linear Regression data Train dengan 80 fitur:6.22
# MAE model Linear Regression data Train dengan 80 fitur:4.74
# R2 model Linear Regression data Train dengan 80 fitur:0.8
# ----------------------------
# MSE model Linear data Test dengan 80 fitur:182.03
# RMSE model Linear data Test dengan 80 fitur:13.49
# MAE model Linear data Test dengan 80 fitur:10.51
# R2 model Linear data Test dengan 80 fitur:0.06
# ==================================================
# CPU times: user 6.3 s, sys: 97 ms, total: 6.4 s
# Wall time: 2.94 s

# %% [markdown]
# ## 150 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [80]
n_trees = [150]

for nfeat in n_feat:
    for ntrees in n_trees:
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur Fisher Score
        x_train_selected = x_train[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]
        x_test_selected = x_test[fisher_ranking.nsmallest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 80 fitur: 38.4
# RMSE model Linear Regression data Train dengan 80 fitur:6.19
# MAE model Linear Regression data Train dengan 80 fitur:4.72
# R2 model Linear Regression data Train dengan 80 fitur:0.8
# ----------------------------
# MSE model Linear data Test dengan 80 fitur:184.25
# RMSE model Linear data Test dengan 80 fitur:13.57
# MAE model Linear data Test dengan 80 fitur:10.58
# R2 model Linear data Test dengan 80 fitur:0.07
# ==================================================
# CPU times: user 4.2 s, sys: 7.99 ms, total: 4.2 s
# Wall time: 4.2 s

# %% [markdown]
# ## 200 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [80]
n_trees = [200]
for nfeat in n_feat:
    for ntrees in n_trees:
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur Fisher Score
        x_train_selected = x_train[fisher_ranking.nlargest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]
        x_test_selected = x_test[fisher_ranking.nlargest(300,columns="Fisher_Ranking").iloc[0:nfeat, 0]]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 80 fitur: 39.17
# RMSE model Linear Regression data Train dengan 80 fitur:6.25
# MAE model Linear Regression data Train dengan 80 fitur:4.77
# R2 model Linear Regression data Train dengan 80 fitur:0.8
# ----------------------------
# MSE model Linear data Test dengan 80 fitur:174.4
# RMSE model Linear data Test dengan 80 fitur:13.21
# MAE model Linear data Test dengan 80 fitur:10.44
# R2 model Linear data Test dengan 80 fitur:0.01
# ==================================================
# CPU times: user 4.97 s, sys: 31.3 ms, total: 5.01 s
# Wall time: 5 s
