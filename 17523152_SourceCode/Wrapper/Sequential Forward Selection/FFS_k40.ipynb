# %% [markdown]
# referensi https://www.analyticsvidhya.com/blog/2021/04/forward-feature-selection-and-its-implementation/

# %%
# #instal library mlxtend
# %pip install mlxtend

# %%
# Import Library
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, KFold, cross_validate
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import time

# %%
#import dataset
df = pd.read_csv('/home/jupyter-17523142/Rama/Dataset/dataset_rama.csv')
X = df.drop(['No', 'Mango Cultivars', 'Vit C (mg/100g)', 'TA (mg/100g)', 'SSC (oBrix)', 'label'], axis = 1)
y_vitc = df.loc[:, 'Vit C (mg/100g)']

# separate dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(
    X, y_vitc, test_size = 0.3, random_state=0)

# %% [markdown]
# ## Seleksi Fitur Forward Selection dengan Linear Regression

# %%
# calling the Linear Regression model
lr_model =  LinearRegression()
sfs = sfs(lr_model, k_features=20, forward=True, verbose=2, scoring='neg_root_mean_squared_error', n_jobs=-1)

# %%
# %%time 

sfs = sfs.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    6.2s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   10.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:   11.3s
# [Parallel(n_jobs=-1)]: Done 1557 out of 1557 | elapsed:   11.6s finished
#
# [2022-07-13 06:23:32] Features: 1/40 -- score: -13.787313513773904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 1556 out of 1556 | elapsed:    2.9s finished
#
# [2022-07-13 06:23:35] Features: 2/40 -- score: -12.378759342766646[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 1396 out of 1555 | elapsed:    3.1s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 1555 out of 1555 | elapsed:    3.1s finished
#
# [2022-07-13 06:23:38] Features: 3/40 -- score: -12.02775078078409[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 1395 out of 1554 | elapsed:    3.0s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 1554 out of 1554 | elapsed:    3.0s finished
#
# [2022-07-13 06:23:41] Features: 4/40 -- score: -11.780227105731935[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 1394 out of 1553 | elapsed:    3.4s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 1553 out of 1553 | elapsed:    3.4s finished
#
# [2022-07-13 06:23:45] Features: 5/40 -- score: -11.618202325658217[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 1552 out of 1552 | elapsed:    3.6s finished
#
# [2022-07-13 06:23:48] Features: 6/40 -- score: -11.364862191982446[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 1392 out of 1551 | elapsed:    3.6s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 1551 out of 1551 | elapsed:    3.7s finished
#
# [2022-07-13 06:23:52] Features: 7/40 -- score: -11.286383938498421[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 1550 out of 1550 | elapsed:    5.0s finished
#
# [2022-07-13 06:23:57] Features: 8/40 -- score: -11.189144017840864[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 1549 out of 1549 | elapsed:    3.6s finished
#
# [2022-07-13 06:24:01] Features: 9/40 -- score: -10.996489084265619[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 1548 out of 1548 | elapsed:    3.5s finished
#
# [2022-07-13 06:24:04] Features: 10/40 -- score: -10.953473777705172[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 1388 out of 1547 | elapsed:    3.5s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 1547 out of 1547 | elapsed:    3.6s finished
#
# [2022-07-13 06:24:08] Features: 11/40 -- score: -10.906252633020575[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 1546 out of 1546 | elapsed:    3.3s finished
#
# [2022-07-13 06:24:11] Features: 12/40 -- score: -10.825633764272926[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 1386 out of 1545 | elapsed:    3.6s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 1545 out of 1545 | elapsed:    3.6s finished
#
# [2022-07-13 06:24:15] Features: 13/40 -- score: -10.755354980624812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 1385 out of 1544 | elapsed:    3.9s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 1544 out of 1544 | elapsed:    4.0s finished
#
# [2022-07-13 06:24:19] Features: 14/40 -- score: -10.74540045084598[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 1384 out of 1543 | elapsed:    4.2s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 1543 out of 1543 | elapsed:    4.2s finished
#
# [2022-07-13 06:24:23] Features: 15/40 -- score: -10.703055098866894[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.6s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 1383 out of 1542 | elapsed:    4.4s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 1542 out of 1542 | elapsed:    4.4s finished
#
# [2022-07-13 06:24:28] Features: 16/40 -- score: -10.687026194696717[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   10.7s
# [Parallel(n_jobs=-1)]: Done 1541 out of 1541 | elapsed:   12.7s finished
#
# [2022-07-13 06:24:41] Features: 17/40 -- score: -10.62561546525142[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 1540 out of 1540 | elapsed:    5.0s finished
#
# [2022-07-13 06:24:46] Features: 18/40 -- score: -10.605310554724548[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 1539 out of 1539 | elapsed:    5.2s finished
#
# [2022-07-13 06:24:51] Features: 19/40 -- score: -10.590518686880598[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 826 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 1538 out of 1538 | elapsed:    5.5s finished
#
# [2022-07-13 06:24:57] Features: 20/40 -- score: -10.325347366652931[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 1537 out of 1537 | elapsed:    5.5s finished
#
# [2022-07-13 06:25:02] Features: 21/40 -- score: -10.182754596854902[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 1536 out of 1536 | elapsed:    5.8s finished
#
# [2022-07-13 06:25:08] Features: 22/40 -- score: -10.015784793209887[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 1376 out of 1535 | elapsed:    5.6s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 1535 out of 1535 | elapsed:    5.7s finished
#
# [2022-07-13 06:25:14] Features: 23/40 -- score: -9.886938316494005[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 1534 out of 1534 | elapsed:    5.9s finished
#
# [2022-07-13 06:25:20] Features: 24/40 -- score: -9.797719744839771[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 1533 out of 1533 | elapsed:    9.8s finished
#
# [2022-07-13 06:25:29] Features: 25/40 -- score: -9.758657991546144[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 820 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 1532 out of 1532 | elapsed:    5.8s finished
#
# [2022-07-13 06:25:35] Features: 26/40 -- score: -9.750851920492604[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 1372 out of 1531 | elapsed:    6.0s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 1531 out of 1531 | elapsed:    6.0s finished
#
# [2022-07-13 06:25:41] Features: 27/40 -- score: -9.744310394378633[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 1371 out of 1530 | elapsed:    6.2s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 1530 out of 1530 | elapsed:    6.3s finished
#
# [2022-07-13 06:25:48] Features: 28/40 -- score: -9.718237887555711[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 1370 out of 1529 | elapsed:    6.4s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 1529 out of 1529 | elapsed:    6.4s finished
#
# [2022-07-13 06:25:54] Features: 29/40 -- score: -9.594043318757459[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 1369 out of 1528 | elapsed:    6.3s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 1528 out of 1528 | elapsed:    6.4s finished
#
# [2022-07-13 06:26:01] Features: 30/40 -- score: -9.490355329244823[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 1527 out of 1527 | elapsed:    6.1s finished
#
# [2022-07-13 06:26:07] Features: 31/40 -- score: -9.404143041573684[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 1526 out of 1526 | elapsed:    6.6s finished
#
# [2022-07-13 06:26:14] Features: 32/40 -- score: -9.33352181068297[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 1366 out of 1525 | elapsed:    6.5s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 1525 out of 1525 | elapsed:    6.6s finished
#
# [2022-07-13 06:26:20] Features: 33/40 -- score: -9.290582992995628[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 1524 out of 1524 | elapsed:    6.9s finished
#
# [2022-07-13 06:26:27] Features: 34/40 -- score: -9.241279815033396[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 1364 out of 1523 | elapsed:    7.1s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 1523 out of 1523 | elapsed:    7.1s finished
#
# [2022-07-13 06:26:34] Features: 35/40 -- score: -9.187080961493354[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 1522 out of 1522 | elapsed:    7.1s finished
#
# [2022-07-13 06:26:42] Features: 36/40 -- score: -9.160786581068182[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 820 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done 1362 out of 1521 | elapsed:    7.0s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 1521 out of 1521 | elapsed:    7.0s finished
#
# [2022-07-13 06:26:49] Features: 37/40 -- score: -9.140523119854382[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 648 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 1013 tasks      | elapsed:    8.0s
# [Parallel(n_jobs=-1)]: Done 1520 out of 1520 | elapsed:   11.1s finished
#
# [2022-07-13 06:27:00] Features: 38/40 -- score: -9.153565791809488[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done 1360 out of 1519 | elapsed:    7.5s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 1519 out of 1519 | elapsed:    7.5s finished
#
# [2022-07-13 06:27:07] Features: 39/40 -- score: -9.138175441256589[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    5.0s
# CPU times: user 3min 38s, sys: 11.2 s, total: 3min 49s
# Wall time: 3min 54s
# [Parallel(n_jobs=-1)]: Done 1359 out of 1518 | elapsed:    7.0s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 1518 out of 1518 | elapsed:    7.1s finished
#
# [2022-07-13 06:27:15] Features: 40/40 -- score: -9.13691357528299

# %%
feat_names = list(sfs.k_feature_names_)
print("Fitur yang diambil adalah: ")
print(feat_names)
len(feat_names)
# Out:
# Fitur yang diambil adalah:
# ['1043.4', '1045.9', '1047.1', '1050.5', '1051', '1052.2', '1052.7', '1054', '1060', '1070.5', '1084.8', '1085.3', '1085.7', '1087.1', '1087.6', '1089.4', '1089.8', '1094.4', '1094.9', '1096.3', '1101.4', '1104.2', '1391', '1422.2', '1424.6', '1425.4', '1427.7', '1439.6', '1446', '1446.8', '1452.5', '1454.1', '1464', '1540.5', '1555.3', '1654.6', '1660.9', '1666.3', '1669.5', '1732']
# 40

# %% [markdown]
# # Prediksi Linear Regression

# %%
#cross validation 10-fold
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [40]

for nfeat in n_feat:
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur SFS
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Linear Regression
        lr_model = LinearRegression()
        
        #Train the model using the training sets
        lr_model.fit(x_train_selected, y_train)
        y_pred_lr = lr_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(lr_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Linear Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")        
        print("MSE model Linear Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_lr), 2))))
        print("RMSE model Linear Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_lr, squared = False), 2))))
        print("MAE model Linear Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_lr), 2))))
        print("R2 model Linear Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_lr), 2))))
        print(" ")
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 40 fitur: 52.9
# RMSE model Linear Regression data Train dengan 40 fitur:7.27
# MAE model Linear Regression data Train dengan 40 fitur:5.63
# R2 model Linear Regression data Train dengan 40 fitur:0.72
# ----------------------------
# MSE model Linear Regression data Test dengan 40 fitur:394.58
# RMSE model Linear Regression data Test dengan 40 fitur:19.86
# MAE model Linear Regression data Test dengan 40 fitur:14.7
# R2 model Linear Regression data Test dengan 40 fitur:1.29
#
# ==================================================
# CPU times: user 6.32 s, sys: 181 ms, total: 6.5 s
# Wall time: 469 ms

# %% [markdown]
# # Prediksi Random Forest Regressor

# %% [markdown]
# ## 100 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [40]
n_trees = [100]

for nfeat in n_feat:
    for ntrees in n_trees: 
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur SFS
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print(" ")
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 40 fitur: 38.16
# RMSE model Linear Regression data Train dengan 40 fitur:6.17
# MAE model Linear Regression data Train dengan 40 fitur:4.72
# R2 model Linear Regression data Train dengan 40 fitur:0.8
# ----------------------------
# MSE model Linear Regression data Test dengan 40 fitur:185.67
# RMSE model Linear Regression data Test dengan 40 fitur:13.63
# MAE model Linear Regression data Test dengan 40 fitur:10.68
# R2 model Linear Regression data Test dengan 40 fitur:0.08
#
# ==================================================
# CPU times: user 5.47 s, sys: 115 ms, total: 5.58 s
# Wall time: 2.45 s

# %% [markdown]
# ## 150 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [40]
n_trees = [150]

for nfeat in n_feat:
    for ntrees in n_trees: 
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur SFS
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print(" ")
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 40 fitur: 37.97
# RMSE model Linear Regression data Train dengan 40 fitur:6.16
# MAE model Linear Regression data Train dengan 40 fitur:4.71
# R2 model Linear Regression data Train dengan 40 fitur:0.8
# ----------------------------
# MSE model Linear Regression data Test dengan 40 fitur:187.78
# RMSE model Linear Regression data Test dengan 40 fitur:13.7
# MAE model Linear Regression data Test dengan 40 fitur:10.77
# R2 model Linear Regression data Test dengan 40 fitur:0.09
#
# ==================================================
# CPU times: user 3.59 s, sys: 19 ms, total: 3.61 s
# Wall time: 3.61 s

# %% [markdown]
# ## 200 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [40]
n_trees = [200]

for nfeat in n_feat:
    for ntrees in n_trees: 
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur SFS
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print(" ")
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 40 fitur: 37.91
# RMSE model Linear Regression data Train dengan 40 fitur:6.15
# MAE model Linear Regression data Train dengan 40 fitur:4.71
# R2 model Linear Regression data Train dengan 40 fitur:0.8
# ----------------------------
# MSE model Linear Regression data Test dengan 40 fitur:186.1
# RMSE model Linear Regression data Test dengan 40 fitur:13.64
# MAE model Linear Regression data Test dengan 40 fitur:10.82
# R2 model Linear Regression data Test dengan 40 fitur:0.08
#
# ==================================================
# CPU times: user 4.86 s, sys: 17.5 ms, total: 4.88 s
# Wall time: 4.87 s
