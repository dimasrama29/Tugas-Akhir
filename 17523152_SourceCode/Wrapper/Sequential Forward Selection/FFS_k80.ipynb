# %% [markdown]
# referensi https://www.analyticsvidhya.com/blog/2021/04/forward-feature-selection-and-its-implementation/

# %%
# #instal library mlxtend
# %pip install mlxtend

# %%
# Import Library
import pandas as pd
from mlxtend.feature_selection import SequentialFeatureSelector as sfs
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, KFold, cross_validate
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import time

# %%
#import dataset
df = pd.read_csv('/home/jupyter-17523142/Rama/Dataset/dataset_rama.csv')
X = df.drop(['No', 'Mango Cultivars', 'Vit C (mg/100g)', 'TA (mg/100g)', 'SSC (oBrix)', 'label'], axis = 1)
y_vitc = df.loc[:, 'Vit C (mg/100g)']

# separate dataset into train and test
x_train, x_test, y_train, y_test = train_test_split(
    X, y_vitc, test_size = 0.3, random_state=0)

# %% [markdown]
# ## Seleksi Fitur Forward Selection dengan Linear Regression

# %%
# calling the Linear Regression model
lr_model =  LinearRegression()
sfs = sfs(lr_model, k_features=80, forward=True, verbose=2, scoring='neg_root_mean_squared_error', n_jobs=-1)

# %%
# %%time 

sfs = sfs.fit(x_train, y_train)
# Out:
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 1557 out of 1557 | elapsed:    9.8s finished
#
# [2022-07-13 06:47:09] Features: 1/80 -- score: -13.787313513773904[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 1397 out of 1556 | elapsed:    2.8s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 1556 out of 1556 | elapsed:    2.8s finished
#
# [2022-07-13 06:47:12] Features: 2/80 -- score: -12.378759342766646[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 1396 out of 1555 | elapsed:    3.0s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 1555 out of 1555 | elapsed:    3.0s finished
#
# [2022-07-13 06:47:15] Features: 3/80 -- score: -12.02775078078409[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 1554 out of 1554 | elapsed:    3.1s finished
#
# [2022-07-13 06:47:18] Features: 4/80 -- score: -11.780227105731935[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   7 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 260 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 826 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 1394 out of 1553 | elapsed:    3.1s remaining:    0.3s
# [Parallel(n_jobs=-1)]: Done 1553 out of 1553 | elapsed:    3.1s finished
#
# [2022-07-13 06:47:21] Features: 5/80 -- score: -11.618202325658217[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 1552 out of 1552 | elapsed:    3.0s finished
#
# [2022-07-13 06:47:25] Features: 6/80 -- score: -11.364862191982446[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 1392 out of 1551 | elapsed:    3.3s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 1551 out of 1551 | elapsed:    3.3s finished
#
# [2022-07-13 06:47:28] Features: 7/80 -- score: -11.286383938498421[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.2s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 1550 out of 1550 | elapsed:    3.3s finished
#
# [2022-07-13 06:47:31] Features: 8/80 -- score: -11.189144017840864[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    2.3s
# [Parallel(n_jobs=-1)]: Done 1549 out of 1549 | elapsed:    3.3s finished
#
# [2022-07-13 06:47:35] Features: 9/80 -- score: -10.996489084265619[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 1548 out of 1548 | elapsed:    3.3s finished
#
# [2022-07-13 06:47:38] Features: 10/80 -- score: -10.953473777705172[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 1388 out of 1547 | elapsed:    3.6s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 1547 out of 1547 | elapsed:    3.7s finished
#
# [2022-07-13 06:47:42] Features: 11/80 -- score: -10.906252633020575[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.5s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 1387 out of 1546 | elapsed:    3.7s remaining:    0.4s
# [Parallel(n_jobs=-1)]: Done 1546 out of 1546 | elapsed:    3.8s finished
#
# [2022-07-13 06:47:45] Features: 12/80 -- score: -10.825633764272926[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 1386 out of 1545 | elapsed:    4.0s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 1545 out of 1545 | elapsed:    4.0s finished
#
# [2022-07-13 06:47:50] Features: 13/80 -- score: -10.755354980624812[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 1544 out of 1544 | elapsed:    5.1s finished
#
# [2022-07-13 06:47:55] Features: 14/80 -- score: -10.74540045084598[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 650 tasks      | elapsed:    6.7s
# [Parallel(n_jobs=-1)]: Done 1015 tasks      | elapsed:    8.4s
# [Parallel(n_jobs=-1)]: Done 1543 out of 1543 | elapsed:   10.2s finished
#
# [2022-07-13 06:48:05] Features: 15/80 -- score: -10.703055098866894[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 822 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 1542 out of 1542 | elapsed:    4.7s finished
#
# [2022-07-13 06:48:10] Features: 16/80 -- score: -10.687026194696717[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 1382 out of 1541 | elapsed:    4.7s remaining:    0.5s
# [Parallel(n_jobs=-1)]: Done 1541 out of 1541 | elapsed:    4.7s finished
#
# [2022-07-13 06:48:15] Features: 17/80 -- score: -10.62561546525142[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 1540 out of 1540 | elapsed:    4.9s finished
#
# [2022-07-13 06:48:20] Features: 18/80 -- score: -10.605310554724548[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 1380 out of 1539 | elapsed:    4.9s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 1539 out of 1539 | elapsed:    5.0s finished
#
# [2022-07-13 06:48:25] Features: 19/80 -- score: -10.590518686880598[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 1538 out of 1538 | elapsed:    5.3s finished
#
# [2022-07-13 06:48:30] Features: 20/80 -- score: -10.325347366652931[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 820 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 1378 out of 1537 | elapsed:    5.4s remaining:    0.6s
# [Parallel(n_jobs=-1)]: Done 1537 out of 1537 | elapsed:    5.5s finished
#
# [2022-07-13 06:48:36] Features: 21/80 -- score: -10.182754596854902[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    3.8s
# [Parallel(n_jobs=-1)]: Done 1536 out of 1536 | elapsed:    5.4s finished
#
# [2022-07-13 06:48:41] Features: 22/80 -- score: -10.015784793209887[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 1535 out of 1535 | elapsed:    5.6s finished
#
# [2022-07-13 06:48:47] Features: 23/80 -- score: -9.886938316494005[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 1534 out of 1534 | elapsed:    5.8s finished
#
# [2022-07-13 06:48:53] Features: 24/80 -- score: -9.797719744839771[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 820 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 1533 out of 1533 | elapsed:    5.8s finished
#
# [2022-07-13 06:48:59] Features: 25/80 -- score: -9.758657991546144[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 1532 out of 1532 | elapsed:    6.0s finished
#
# [2022-07-13 06:49:05] Features: 26/80 -- score: -9.750851920492604[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.1s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 1372 out of 1531 | elapsed:    5.9s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 1531 out of 1531 | elapsed:    6.0s finished
#
# [2022-07-13 06:49:11] Features: 27/80 -- score: -9.744310394378633[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.4s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 1530 out of 1530 | elapsed:    6.2s finished
#
# [2022-07-13 06:49:17] Features: 28/80 -- score: -9.718237887555711[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.2s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 1370 out of 1529 | elapsed:    6.0s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 1529 out of 1529 | elapsed:    6.1s finished
#
# [2022-07-13 06:49:23] Features: 29/80 -- score: -9.594043318757459[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   8 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 262 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 828 tasks      | elapsed:    4.7s
# [Parallel(n_jobs=-1)]: Done 1369 out of 1528 | elapsed:    6.4s remaining:    0.7s
# [Parallel(n_jobs=-1)]: Done 1528 out of 1528 | elapsed:    6.4s finished
#
# [2022-07-13 06:49:30] Features: 30/80 -- score: -9.490355329244823[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    4.9s
# [Parallel(n_jobs=-1)]: Done 1527 out of 1527 | elapsed:    6.9s finished
#
# [2022-07-13 06:49:37] Features: 31/80 -- score: -9.404143041573684[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 1526 out of 1526 | elapsed:    6.8s finished
#
# [2022-07-13 06:49:43] Features: 32/80 -- score: -9.33352181068297[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.8s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    5.3s
# [Parallel(n_jobs=-1)]: Done 1366 out of 1525 | elapsed:    7.1s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 1525 out of 1525 | elapsed:    7.1s finished
#
# [2022-07-13 06:49:51] Features: 33/80 -- score: -9.290582992995628[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    2.6s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 1524 out of 1524 | elapsed:    7.0s finished
#
# [2022-07-13 06:49:58] Features: 34/80 -- score: -9.241279815033396[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.5s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 1364 out of 1523 | elapsed:    6.9s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 1523 out of 1523 | elapsed:    6.9s finished
#
# [2022-07-13 06:50:05] Features: 35/80 -- score: -9.187080961493354[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    5.0s
# [Parallel(n_jobs=-1)]: Done 1522 out of 1522 | elapsed:    6.9s finished
#
# [2022-07-13 06:50:12] Features: 36/80 -- score: -9.160786581068182[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 1362 out of 1521 | elapsed:    7.2s remaining:    0.8s
# [Parallel(n_jobs=-1)]: Done 1521 out of 1521 | elapsed:    7.2s finished
#
# [2022-07-13 06:50:19] Features: 37/80 -- score: -9.140523119854382[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 1520 out of 1520 | elapsed:    7.7s finished
#
# [2022-07-13 06:50:27] Features: 38/80 -- score: -9.153565791809488[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:    2.9s
# [Parallel(n_jobs=-1)]: Done 820 tasks      | elapsed:    5.4s
# [Parallel(n_jobs=-1)]: Done 1360 out of 1519 | elapsed:    7.4s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 1519 out of 1519 | elapsed:    7.4s finished
#
# [2022-07-13 06:50:34] Features: 39/80 -- score: -9.138175441256589[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    2.7s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 1518 out of 1518 | elapsed:    7.7s finished
#
# [2022-07-13 06:50:42] Features: 40/80 -- score: -9.13691357528299[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 816 tasks      | elapsed:    5.5s
# [Parallel(n_jobs=-1)]: Done 1358 out of 1517 | elapsed:    7.7s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 1517 out of 1517 | elapsed:    7.7s finished
#
# [2022-07-13 06:50:50] Features: 41/80 -- score: -9.146564699619097[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:    3.0s
# [Parallel(n_jobs=-1)]: Done 820 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 1516 out of 1516 | elapsed:    8.0s finished
#
# [2022-07-13 06:50:58] Features: 42/80 -- score: -9.149655093089333[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.6s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    5.8s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:    8.7s
# [Parallel(n_jobs=-1)]: Done 1515 out of 1515 | elapsed:   12.0s finished
#
# [2022-07-13 06:51:10] Features: 43/80 -- score: -9.183105243977623[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:    9.1s
# [Parallel(n_jobs=-1)]: Done 1514 out of 1514 | elapsed:   12.2s finished
#
# [2022-07-13 06:51:22] Features: 44/80 -- score: -9.209084102398474[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 820 tasks      | elapsed:    5.6s
# [Parallel(n_jobs=-1)]: Done 1354 out of 1513 | elapsed:    7.7s remaining:    0.9s
# [Parallel(n_jobs=-1)]: Done 1513 out of 1513 | elapsed:    7.7s finished
#
# [2022-07-13 06:51:30] Features: 45/80 -- score: -9.23362362677204[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    3.3s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:    9.6s
# [Parallel(n_jobs=-1)]: Done 1512 out of 1512 | elapsed:   12.8s finished
#
# [2022-07-13 06:51:43] Features: 46/80 -- score: -9.254247744307898[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 818 tasks      | elapsed:    6.1s
# [Parallel(n_jobs=-1)]: Done 1352 out of 1511 | elapsed:    8.3s remaining:    1.0s
# [Parallel(n_jobs=-1)]: Done 1511 out of 1511 | elapsed:    8.4s finished
#
# [2022-07-13 06:51:51] Features: 47/80 -- score: -9.288386330166386[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    6.3s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 1510 out of 1510 | elapsed:   13.0s finished
#
# [2022-07-13 06:52:04] Features: 48/80 -- score: -9.300698348243177[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:    5.7s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:    9.3s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:   13.2s
# [Parallel(n_jobs=-1)]: Done 1509 out of 1509 | elapsed:   13.8s finished
#
# [2022-07-13 06:52:18] Features: 49/80 -- score: -9.318646977959533[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=-1)]: Done 648 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 1013 tasks      | elapsed:    9.5s
# [Parallel(n_jobs=-1)]: Done 1508 out of 1508 | elapsed:   13.0s finished
#
# [2022-07-13 06:52:31] Features: 50/80 -- score: -9.337137228826219[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:    3.2s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:    5.9s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:   14.1s
# [Parallel(n_jobs=-1)]: Done 1507 out of 1507 | elapsed:   14.7s finished
#
# [2022-07-13 06:52:46] Features: 51/80 -- score: -9.342504886185717[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.4s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    3.5s
# [Parallel(n_jobs=-1)]: Done 648 tasks      | elapsed:    6.5s
# [Parallel(n_jobs=-1)]: Done 1013 tasks      | elapsed:   10.0s
# [Parallel(n_jobs=-1)]: Done 1506 out of 1506 | elapsed:   13.3s finished
#
# [2022-07-13 06:52:59] Features: 52/80 -- score: -9.35821642583286[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 1505 out of 1505 | elapsed:   14.2s finished
#
# [2022-07-13 06:53:14] Features: 53/80 -- score: -9.391255349498643[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   5 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 256 tasks      | elapsed:    3.7s
# [Parallel(n_jobs=-1)]: Done 651 tasks      | elapsed:    6.4s
# [Parallel(n_jobs=-1)]: Done 1016 tasks      | elapsed:   10.5s
# [Parallel(n_jobs=-1)]: Done 1504 out of 1504 | elapsed:   13.9s finished
#
# [2022-07-13 06:53:28] Features: 54/80 -- score: -9.411952804695174[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    7.0s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 1503 out of 1503 | elapsed:   14.6s finished
#
# [2022-07-13 06:53:42] Features: 55/80 -- score: -9.466375187347813[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:    6.6s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   10.8s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:   15.7s
# [Parallel(n_jobs=-1)]: Done 1502 out of 1502 | elapsed:   16.3s finished
#
# [2022-07-13 06:53:59] Features: 56/80 -- score: -9.518827627856396[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    7.3s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   11.2s
# [Parallel(n_jobs=-1)]: Done 1501 out of 1501 | elapsed:   14.7s finished
#
# [2022-07-13 06:54:13] Features: 57/80 -- score: -9.533721065381538[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    3.6s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    6.8s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   11.0s
# [Parallel(n_jobs=-1)]: Done 1500 out of 1500 | elapsed:   14.8s finished
#
# [2022-07-13 06:54:28] Features: 58/80 -- score: -9.584293217357608[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    7.5s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   11.8s
# [Parallel(n_jobs=-1)]: Done 1499 out of 1499 | elapsed:   15.8s finished
#
# [2022-07-13 06:54:44] Features: 59/80 -- score: -9.61865786668991[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   11.6s
# [Parallel(n_jobs=-1)]: Done 1498 out of 1498 | elapsed:   15.5s finished
#
# [2022-07-13 06:55:00] Features: 60/80 -- score: -9.731956445388374[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.9s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 1497 out of 1497 | elapsed:   16.5s finished
#
# [2022-07-13 06:55:16] Features: 61/80 -- score: -9.79670931784878[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 1496 out of 1496 | elapsed:   16.7s finished
#
# [2022-07-13 06:55:33] Features: 62/80 -- score: -9.879802366161483[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:    3.9s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:    7.6s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   12.5s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done 1495 out of 1495 | elapsed:   18.9s finished
#
# [2022-07-13 06:55:52] Features: 63/80 -- score: -10.0191249963397[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   12.8s
# [Parallel(n_jobs=-1)]: Done 1494 out of 1494 | elapsed:   17.1s finished
#
# [2022-07-13 06:56:09] Features: 64/80 -- score: -10.085602426286517[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 648 tasks      | elapsed:    7.7s
# [Parallel(n_jobs=-1)]: Done 1013 tasks      | elapsed:   12.3s
# [Parallel(n_jobs=-1)]: Done 1493 out of 1493 | elapsed:   16.2s finished
#
# [2022-07-13 06:56:25] Features: 65/80 -- score: -10.168948160630094[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    7.8s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   12.4s
# [Parallel(n_jobs=-1)]: Done 1492 out of 1492 | elapsed:   16.7s finished
#
# [2022-07-13 06:56:42] Features: 66/80 -- score: -10.337521428504745[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 1491 out of 1491 | elapsed:   17.0s finished
#
# [2022-07-13 06:56:59] Features: 67/80 -- score: -10.449457103994709[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.2s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   12.6s
# [Parallel(n_jobs=-1)]: Done 1490 out of 1490 | elapsed:   16.7s finished
#
# [2022-07-13 06:57:16] Features: 68/80 -- score: -10.572097218127622[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 250 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 648 tasks      | elapsed:    7.9s
# [Parallel(n_jobs=-1)]: Done 1013 tasks      | elapsed:   12.7s
# [Parallel(n_jobs=-1)]: Done 1489 out of 1489 | elapsed:   16.9s finished
#
# [2022-07-13 06:57:33] Features: 69/80 -- score: -10.664349552474153[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    8.3s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 1488 out of 1488 | elapsed:   17.3s finished
#
# [2022-07-13 06:57:50] Features: 70/80 -- score: -10.938844681957058[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   2 tasks      | elapsed:    0.8s
# [Parallel(n_jobs=-1)]: Done 205 tasks      | elapsed:    4.3s
# [Parallel(n_jobs=-1)]: Done 488 tasks      | elapsed:    8.1s
# [Parallel(n_jobs=-1)]: Done 853 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 1298 tasks      | elapsed:   19.2s
# [Parallel(n_jobs=-1)]: Done 1487 out of 1487 | elapsed:   19.8s finished
#
# [2022-07-13 06:58:10] Features: 71/80 -- score: -11.205485399814213[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   4 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 254 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 650 tasks      | elapsed:    8.9s
# [Parallel(n_jobs=-1)]: Done 1015 tasks      | elapsed:   14.3s
# [Parallel(n_jobs=-1)]: Done 1486 out of 1486 | elapsed:   18.9s finished
#
# [2022-07-13 06:58:29] Features: 72/80 -- score: -11.43707637627637[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    8.6s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   13.7s
# [Parallel(n_jobs=-1)]: Done 1485 out of 1485 | elapsed:   18.4s finished
#
# [2022-07-13 06:58:48] Features: 73/80 -- score: -11.974680956237213[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.2s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.5s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    8.5s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   13.1s
# [Parallel(n_jobs=-1)]: Done 1484 out of 1484 | elapsed:   17.6s finished
#
# [2022-07-13 06:59:05] Features: 74/80 -- score: -12.56441764372084[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.6s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   14.2s
# [Parallel(n_jobs=-1)]: Done 1483 out of 1483 | elapsed:   18.4s finished
#
# [2022-07-13 06:59:24] Features: 75/80 -- score: -12.64940217970971[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.4s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    9.0s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   14.4s
# [Parallel(n_jobs=-1)]: Done 1482 out of 1482 | elapsed:   19.2s finished
#
# [2022-07-13 06:59:43] Features: 76/80 -- score: -12.821001433518607[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.3s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    4.8s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   15.1s
# [Parallel(n_jobs=-1)]: Done 1481 out of 1481 | elapsed:   19.9s finished
#
# [2022-07-13 07:00:03] Features: 77/80 -- score: -13.479493871849305[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  10 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 266 tasks      | elapsed:    5.2s
# [Parallel(n_jobs=-1)]: Done 656 tasks      | elapsed:    9.7s
# [Parallel(n_jobs=-1)]: Done 1021 tasks      | elapsed:   15.2s
# [Parallel(n_jobs=-1)]: Done 1480 out of 1480 | elapsed:   19.5s finished
#
# [2022-07-13 07:00:23] Features: 78/80 -- score: -15.168546957077234[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.1s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    9.4s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   14.9s
# [Parallel(n_jobs=-1)]: Done 1479 out of 1479 | elapsed:   19.7s finished
#
# [2022-07-13 07:00:43] Features: 79/80 -- score: -15.921827475282374[Parallel(n_jobs=-1)]: Using backend LokyBackend with 80 concurrent workers.
# [Parallel(n_jobs=-1)]: Done   3 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=-1)]: Done 252 tasks      | elapsed:    5.1s
# [Parallel(n_jobs=-1)]: Done 649 tasks      | elapsed:    9.8s
# [Parallel(n_jobs=-1)]: Done 1014 tasks      | elapsed:   15.7s
# CPU times: user 13min 45s, sys: 28.9 s, total: 14min 14s
# Wall time: 14min 3s
# [Parallel(n_jobs=-1)]: Done 1478 out of 1478 | elapsed:   20.3s finished
#
# [2022-07-13 07:01:03] Features: 80/80 -- score: -19.371340515482583

# %%
feat_names = list(sfs.k_feature_names_)
print("Fitur yang diambil adalah: ")
print(feat_names)
len(feat_names)
# Out:
# Fitur yang diambil adalah:
# ['1009.6', '1041.7', '1043.4', '1045.9', '1047.1', '1047.6', '1048.4', '1050.5', '1051', '1052.2', '1052.7', '1054', '1057.4', '1060', '1062.6', '1065.7', '1070.5', '1081.7', '1084.8', '1085.3', '1085.7', '1086.6', '1087.1', '1087.6', '1088.9', '1089.4', '1089.8', '1091.2', '1094.4', '1094.9', '1096.3', '1098.6', '1100.5', '1101.4', '1104.2', '1115.2', '1149.3', '1390.2', '1391', '1397.7', '1406', '1411.4', '1414.5', '1422.2', '1424.6', '1425.4', '1427.7', '1436.4', '1439.6', '1446', '1446.8', '1450.9', '1452.5', '1454.1', '1464', '1466.5', '1485', '1485.8', '1490.1', '1494.4', '1518.9', '1521.6', '1527.8', '1528.7', '1536', '1536.9', '1540.5', '1555.3', '1559.1', '1560', '1654.6', '1659.9', '1660.9', '1664.1', '1666.3', '1669.5', '1674.9', '1680.3', '1681.4', '1732']
# 80

# %% [markdown]
# # Prediksi Linear Regression

# %%
#cross validation 10-fold
cv = KFold(n_splits=10, random_state=1, shuffle=True)

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [80]

for nfeat in n_feat:
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur SFS
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Linear Regression
        lr_model = LinearRegression()
        
        #Train the model using the training sets
        lr_model.fit(x_train_selected, y_train)
        y_pred_lr = lr_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(lr_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Linear Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Linear Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")        
        print("MSE model Linear Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_lr), 2))))
        print("RMSE model Linear Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_lr, squared = False), 2))))
        print("MAE model Linear Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_lr), 2))))
        print("R2 model Linear Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_lr), 2))))
        print(" ")
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 80 fitur: 39.38
# RMSE model Linear Regression data Train dengan 80 fitur:6.26
# MAE model Linear Regression data Train dengan 80 fitur:4.64
# R2 model Linear Regression data Train dengan 80 fitur:0.79
# ----------------------------
# MSE model Linear Regression data Test dengan 80 fitur:457.57
# RMSE model Linear Regression data Test dengan 80 fitur:21.39
# MAE model Linear Regression data Test dengan 80 fitur:15.88
# R2 model Linear Regression data Test dengan 80 fitur:1.65
#
# ==================================================
# CPU times: user 7.56 s, sys: 290 ms, total: 7.85 s
# Wall time: 450 ms

# %% [markdown]
# # Prediksi Random Forest Regressor

# %% [markdown]
# ## 100 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [80]
n_trees = [100]

for nfeat in n_feat:
    for ntrees in n_trees: 
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur SFS
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print(" ")
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 80 fitur: 38.53
# RMSE model Linear Regression data Train dengan 80 fitur:6.2
# MAE model Linear Regression data Train dengan 80 fitur:4.72
# R2 model Linear Regression data Train dengan 80 fitur:0.8
# ----------------------------
# MSE model Linear Regression data Test dengan 80 fitur:185.62
# RMSE model Linear Regression data Test dengan 80 fitur:13.62
# MAE model Linear Regression data Test dengan 80 fitur:10.75
# R2 model Linear Regression data Test dengan 80 fitur:0.08
#
# ==================================================
# CPU times: user 5.93 s, sys: 95.3 ms, total: 6.02 s
# Wall time: 3.43 s

# %% [markdown]
# ## 150 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [80]
n_trees = [150]

for nfeat in n_feat:
    for ntrees in n_trees: 
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur SFS
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print(" ")
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 80 fitur: 38.43
# RMSE model Linear Regression data Train dengan 80 fitur:6.19
# MAE model Linear Regression data Train dengan 80 fitur:4.73
# R2 model Linear Regression data Train dengan 80 fitur:0.8
# ----------------------------
# MSE model Linear Regression data Test dengan 80 fitur:185.61
# RMSE model Linear Regression data Test dengan 80 fitur:13.62
# MAE model Linear Regression data Test dengan 80 fitur:10.79
# R2 model Linear Regression data Test dengan 80 fitur:0.08
#
# ==================================================
# CPU times: user 4.84 s, sys: 34 ms, total: 4.88 s
# Wall time: 4.87 s

# %% [markdown]
# ## 200 Trees

# %%
# %%time

#tentukan metode scoring yang digunakan
metrics = {'rmse': 'neg_root_mean_squared_error',
               'mse': 'neg_mean_squared_error',
               'mae': 'neg_mean_absolute_error',
               'r2': 'r2'} 

n_feat = [80]
n_trees = [200]

for nfeat in n_feat:
    for ntrees in n_trees: 
        print("==================================================")
        
        #ambil n fitur input hasil seleksi fitur SFS
        x_train_selected = x_train[feat_names].iloc[:,0:nfeat]
        x_test_selected = x_test[feat_names].iloc[:,0:nfeat]

        #Create a Random Forest Regression
        rfg_model = RandomForestRegressor(n_estimators=ntrees, random_state=100)
        
        #Train the model using the training sets
        rfg_model.fit(x_train_selected, y_train)
        y_pred_rfg = rfg_model.predict(x_test_selected)

        #hitung score model dari data train
        scores = cross_validate(rfg_model, x_train_selected, y_train, scoring=metrics, cv=cv, return_train_score=True)

        print("MSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur: " 
              + str(abs(round(scores['train_mse'].mean(), 2))))
        print("RMSE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_rmse'].mean(), 2))))
        print("MAE model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs(round(scores['train_mae'].mean(), 2))))
        print("R2 model Random Forest Regression data Train dengan " + str(nfeat) + " fitur:"
              + str(abs((round(scores['train_r2'].mean(), 2)))))    
        print("----------------------------")
        print("MSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg), 2))))
        print("RMSE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_squared_error(y_test, y_pred_rfg, squared = False), 2))))
        print("MAE model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(mean_absolute_error(y_test, y_pred_rfg), 2))))
        print("R2 model Random Forest Regression data Test dengan " + str(nfeat) + " fitur:" 
          + str(abs(round(r2_score(y_test, y_pred_rfg), 2))))
        print(" ")
        print("==================================================")
# Out:
# ==================================================
# MSE model Linear Regression data Train dengan 80 fitur: 38.39
# RMSE model Linear Regression data Train dengan 80 fitur:6.19
# MAE model Linear Regression data Train dengan 80 fitur:4.73
# R2 model Linear Regression data Train dengan 80 fitur:0.8
# ----------------------------
# MSE model Linear Regression data Test dengan 80 fitur:184.11
# RMSE model Linear Regression data Test dengan 80 fitur:13.57
# MAE model Linear Regression data Test dengan 80 fitur:10.8
# R2 model Linear Regression data Test dengan 80 fitur:0.07
#
# ==================================================
# CPU times: user 6.27 s, sys: 50 ms, total: 6.32 s
# Wall time: 6.32 s
